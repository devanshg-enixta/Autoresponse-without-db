# %%
import pandas as pd
import csv
import unicodedata
import glob
from itertools import *

# %%
review_file = pd.read_csv('source_reviews_for_response_generation_2018-04-25 15_06_13.804171.csv',encoding='utf-8',quoting=csv.QUOTE_ALL)
review_file.dropna(subset=['review_text'],inplace=True)
#review_file.source_review_id = review_file.source_review_id.astype(str)
#review_file.id = review_file.id.astype(int)
#review_file.id = review_file.id.astype(str)

#review_file.to_csv('source_reviews_for_response_generation_2018-04-24 11_59_28.650544.csv',encoding='utf-8',index=False)

# %%
list(review_file.id.unique())
# Out:
# [113007,
#  112962,
#  112662,
#  112570,
#  112620,
#  113268,
#  112885,
#  114004,
#  113132,
#  113727,
#  112679,
#  113341,
#  112730,
#  112528,
#  112490,
#  112982,
#  113066,
#  112993,
#  112886,
#  112479,
#  113949,
#  113855,
#  112640,
#  112934,
#  113496,
#  113269,
#  112953,
#  112731,
#  113051,
#  112544,
#  113951,
#  112532,
#  113271,
#  112883,
#  113151,
#  112984,
#  113068,
#  112985,
#  113673,
#  112661,
#  112954,
#  113108,
#  112591,
#  113174,
#  113192,
#  112672,
#  113952,
#  113423,
#  112973,
#  113950,
#  112471,
#  112809,
#  113270,
#  112826,
#  112492,
#  113150,
#  112961,
#  112970,
#  113173,
#  113010,
#  112476,
#  113856,
#  106401,
#  108394,
#  107047,
#  107466,
#  105996,
#  112566,
#  109514,
#  114412,
#  109258,
#  110498,
#  112578,
#  107093,
#  106197,
#  106588,
#  109703,
#  109300,
#  106427,
#  110199,
#  106815,
#  106350,
#  108370,
#  108761,
#  107181,
#  108846,
#  109677,
#  111158,
#  107369,
#  110259,
#  108847,
#  107987,
#  108733,
#  106535,
#  106684,
#  106648,
#  113427,
#  109171,
#  113052,
#  108935,
#  109589,
#  109928,
#  110156,
#  107624,
#  113322,
#  107695,
#  107921,
#  108547,
#  110574,
#  110382,
#  112714,
#  108828,
#  109496,
#  109291,
#  113194,
#  106549,
#  109073,
#  107062,
#  107578,
#  110422,
#  106017,
#  114289,
#  106602,
#  109395,
#  106809,
#  110543,
#  110685,
#  110429,
#  110710,
#  109354,
#  109478,
#  108815,
#  106474,
#  110506,
#  110210,
#  112801,
#  113394,
#  110686,
#  108355,
#  109688,
#  106779,
#  110375,
#  109730,
#  107121,
#  113112,
#  110144,
#  113152,
#  106603,
#  112664,
#  107410,
#  105991,
#  107905,
#  110718,
#  107456,
#  106422,
#  106515,
#  108390,
#  107198,
#  109530,
#  109193,
#  110180,
#  113172,
#  110423,
#  106597,
#  108028,
#  108145,
#  110044,
#  111160,
#  107644,
#  108590,
#  110346,
#  109601,
#  108171,
#  107581,
#  107688,
#  107929,
#  106790,
#  109986,
#  107686,
#  111182,
#  110576,
#  110722,
#  112612,
#  109803,
#  107713,
#  107359,
#  109183,
#  106400,
#  109754,
#  110468,
#  113421,
#  109659,
#  109674,
#  107399,
#  108576,
#  106617,
#  109422,
#  109163,
#  108535,
#  107865,
#  113114,
#  110596,
#  107285,
#  106662,
#  106127,
#  107187,
#  106971,
#  111057,
#  107620,
#  107024,
#  109712,
#  106770,
#  108226,
#  110148,
#  106544,
#  107049,
#  106218,
#  107633,
#  107934,
#  112675,
#  106066,
#  110503,
#  108235,
#  109016,
#  110298,
#  107112,
#  108487,
#  109225,
#  108759,
#  107293,
#  110687,
#  110702,
#  106265,
#  109817,
#  106340,
#  110500,
#  106193,
#  106686,
#  111103,
#  113148,
#  110984,
#  110690,
#  112704,
#  106810,
#  108011,
#  108173,
#  112776,
#  109613,
#  108816,
#  113286,
#  109088,
#  110370,
#  106613,
#  108724,
#  110656,
#  107155,
#  110195,
#  108534,
#  113058,
#  108869,
#  110709,
#  110508,
#  107718,
#  110043,
#  107521,
#  113426,
#  106118,
#  107387,
#  107243,
#  109386,
#  106156,
#  107091,
#  106013,
#  109639,
#  109680,
#  108451,
#  106757,
#  109250,
#  108749,
#  108664,
#  110007,
#  106116,
#  106414,
#  107505,
#  107083,
#  106131,
#  107855,
#  109477,
#  108591,
#  107023,
#  113294,
#  111141,
#  107144,
#  108861,
#  109972,
#  111003,
#  109433,
#  109963,
#  106871,
#  106953,
#  108555,
#  112588,
#  108023,
#  109194,
#  109414,
#  107902,
#  110412,
#  110972,
#  108934,
#  108358,
#  107842,
#  113357,
#  108531,
#  111164,
#  107125,
#  108927,
#  108580,
#  107871,
#  110358,
#  107447,
#  113229,
#  108460,
#  107694,
#  107993,
#  110042,
#  112686,
#  107610,
#  110284,
#  109858,
#  108941,
#  108780,
#  110692,
#  109321,
#  106818,
#  108915,
#  113133,
#  113469,
#  110542,
#  106072,
#  106538,
#  106495,
#  106765,
#  108285,
#  109617,
#  109112,
#  106392,
#  110995,
#  107316,
#  109826,
#  106507,
#  107101,
#  112887,
#  108362,
#  108785,
#  110083,
#  109432,
#  108530,
#  106612,
#  107605,
#  110605,
#  111186,
#  108837,
#  109418,
#  109504,
#  106853,
#  106468,
#  107502,
#  109953,
#  108978,
#  107557,
#  109620,
#  106433,
#  106976,
#  113059,
#  110446,
#  107812,
#  106042,
#  109586,
#  106334,
#  108065,
#  109318,
#  108441,
#  109240,
#  108218,
#  113197,
#  113315,
#  107606,
#  106188,
#  106150,
#  111185,
#  107843,
#  110108,
#  108295,
#  109136,
#  108553,
#  107697,
#  110299,
#  109396,
#  107189,
#  107866,
#  113081,
#  108518,
#  106404,
#  107278,
#  109481,
#  108194,
#  106085,
#  107767,
#  112999,
#  110472,
#  106493,
#  106444,
#  112785,
#  108222,
#  106528,
#  108754,
#  106641,
#  106962,
#  107452,
#  110667,
#  112665,
#  110634,
#  106224,
#  107208,
#  110968,
#  112464,
#  107080,
#  112515,
#  107518,
#  109469,
#  110413,
#  108710,
#  107857,
#  106089,
#  109144,
#  108558,
#  106373,
#  108730,
#  110205,
#  108150,
#  108643,
#  109575,
#  106791,
#  110578,
#  109809,
#  107722,
#  106694,
#  107962,
#  106548,
#  108674,
#  106310,
#  108753,
#  109926,
#  109349,
#  110648,
#  107103,
#  106185,
#  106393,
#  106327,
#  106716,
#  109734,
#  110002,
#  110366,
#  106257,
#  108984,
#  107401,
#  111138,
#  106547,
#  107560,
#  110389,
#  109632,
#  112509,
#  108294,
#  107808,
#  109377,
#  107201,
#  112827,
#  107712,
#  106231,
#  109952,
#  109197,
#  108097,
#  107072,
#  110306,
#  108301,
#  107483,
#  109908,
#  107379,
#  107642,
#  109026,
#  107874,
#  108423,
#  107717,
#  107790,
#  108333,
#  108307,
#  108019,
#  110138,
#  110481,
#  107344,
#  106539,
#  107494,
#  110287,
#  108867,
#  110147,
#  106204,
#  106003,
#  107471,
#  108734,
#  106430,
#  112508,
#  106079,
#  107875,
#  108248,
#  107134,
#  110457,
#  109233,
#  106553,
#  112696,
#  110460,
#  107590,
#  113060,
#  109702,
#  109011,
#  107864,
#  106968,
#  107117,
#  113355,
#  111193,
#  108288,
#  106176,
#  112963,
#  108427,
#  110129,
#  107777,
#  107573,
#  110417,
#  106864,
#  106919,
#  107281,
#  107989,
#  107460,
#  112643,
#  108005,
#  106745,
#  106364,
#  110062,
#  108273,
#  108985,
#  107098,
#  109184,
#  106380,
#  108638,
#  110028,
#  113581,
#  110361,
#  110096,
#  108276,
#  110696,
#  111175,
#  109415,
#  109079,
#  109337,
#  109464,
#  106032,
#  111161,
#  107527,
#  113130,
#  108213,
#  108574,
#  106428,
#  113324,
#  106847,
#  106676,
#  107878,
#  107630,
#  110351,
#  107920,
#  113397,
#  113083,
#  109550,
#  109622,
#  112497,
#  110490,
#  107599,
#  109142,
#  109521,
#  108681,
#  107846,
#  110310,
#  109784,
#  107360,
#  108442,
#  106436,
#  110480,
#  109687,
#  107113,
#  109723,
#  108907,
#  109765,
#  107308,
#  110251,
#  107048,
#  110627,
#  106651,
#  109132,
#  110143,
#  106216,
#  109906,
#  109628,
#  110510,
#  109185,
#  108312,
#  113075,
#  108917,
#  107576,
#  111013,
#  108468,
#  109280,
#  111230,
#  109762,
#  106110,
#  109582,
#  112976,
#  110350,
#  106701,
#  109663,
#  112769,
#  110133,
#  106794,
#  107852,
#  108608,
#  109149,
#  108121,
#  109074,
#  106148,
#  106874,
#  111047,
#  110119,
#  113119,
#  109312,
#  107562,
#  113180,
#  109486,
#  110193,
#  108937,
#  111202,
#  107402,
#  106362,
#  110023,
#  109630,
#  108618,
#  108119,
#  111180,
#  107128,
#  109400,
#  109263,
#  106671,
#  107698,
#  107656,
#  106726,
#  106585,
#  108838,
#  112608,
#  109000,
#  110569,
#  109054,
#  106319,
#  110613,
#  110154,
#  107096,
#  109141,
#  106155,
#  111040,
#  109880,
#  109281,
#  108706,
#  110557,
#  108809,
#  109740,
#  112718,
#  107114,
#  110733,
#  108901,
#  107571,
#  106035,
#  108963,
#  106560,
#  106620,
#  106642,
#  108045,
#  108497,
#  109738,
#  113054,
#  110546,
#  106826,
#  107400,
#  110548,
#  110019,
#  107577,
#  106183,
#  111029,
#  109462,
#  111030,
#  107345,
#  113833,
#  111154,
#  110598,
#  106406,
#  107421,
#  113011,
#  108729,
#  108800,
#  108598,
#  109050,
#  109844,
#  106777,
#  106632,
#  109025,
#  113429,
#  106590,
#  106485,
#  109795,
#  107628,
#  112879,
#  110038,
#  106593,
#  107975,
#  108522,
#  108317,
#  107806,
#  106719,
#  113517,
#  112975,
#  114272,
#  112590,
#  109454,
#  107670,
#  110268,
#  106418,
#  106950,
#  113082,
#  110434,
#  107831,
#  107306,
#  111135,
#  109931,
#  109867,
#  107707,
#  107020,
#  107157,
#  111140,
#  107738,
#  111163,
#  112763,
#  111144,
#  106691,
#  106178,
#  112824,
#  110323,
#  109943,
#  107981,
#  107771,
#  106592,
#  107544,
#  110017,
#  105994,
#  108367,
#  110398,
#  107868,
#  112484,
#  107805,
#  106575,
#  109002,
#  108053,
#  107650,
#  109883,
#  109781,
#  108430,
#  110174,
#  110267,
#  106019,
#  106654,
#  109461,
#  109843,
#  112594,
#  110342,
#  109172,
#  106972,
#  109608,
#  107233,
#  106744,
#  109666,
#  112764,
#  110716,
#  107766,
#  113474,
#  107490,
#  108401,
#  108615,
#  107499,
#  106388,
#  108503,
#  107416,
#  107362,
#  112939,
#  106670,
#  112814,
#  107297,
#  109997,
#  113231,
#  108279,
#  109297,
#  109861,
#  106230,
#  108562,
#  106673,
#  106269,
#  106034,
#  107164,
#  108552,
#  107540,
#  110514,
#  107264,
#  110979,
#  110334,
#  112813,
#  110256,
#  108403,
#  107665,
#  108622,
#  106349,
#  110762,
#  107984,
#  107021,
#  107890,
#  108949,
#  107530,
#  108600,
#  107057,
#  107647,
#  106532,
#  106712,
#  108972,
#  107709,
#  107531,
#  109407,
#  108742,
#  110501,
#  106888,
#  106986,
#  108249,
#  112583,
#  108900,
#  110535,
#  106293,
#  112837,
#  107088,
#  106954,
#  108966,
#  108924,
#  109129,
#  108495,
#  106124,
#  109116,
#  111213,
#  107161,
#  110201,
#  110974,
#  107667,
#  107453,
#  107522,
#  110105,
#  110699,
#  108691,
#  107204,
#  107922,
#  107160,
#  108347,
#  106580,
#  109780,
#  109366,
#  110352,
#  108087,
#  113047,
#  106753,
#  106630,
#  113360,
#  106420,
#  106479,
#  109143,
#  107377,
#  112758,
#  106472,
#  110579,
#  109528,
#  109387,
#  106657,
#  109493,
#  106056,
#  109830,
#  108054,
#  110378,
#  110273,
#  108379,
#  108103,
#  106483,
#  106598,
#  108541,
#  106001,
#  113117,
#  110091,
#  107731,
#  108993,
#  113080,
#  112997,
#  107536,
#  106805,
#  109538,
#  110191,
#  108537,
#  107548,
#  106649,
#  108792,
#  110668,
#  108951,
#  112834,
#  108825,
#  107324,
#  108260,
#  108255,
#  110274,
#  112930,
#  110328,
#  108671,
#  106161,
#  107094,
#  109145,
#  112618,
#  106179,
#  110615,
#  108142,
#  106398,
#  107305,
#  109465,
#  111069,
#  107318,
#  107735,
#  112995,
#  110541,
#  111205,
#  109633,
#  106908,
#  113232,
#  113195,
#  107912,
#  108791,
#  106210,
#  109440,
#  107482,
#  112598,
#  107437,
#  109286,
#  106755,
#  110060,
#  108033,
#  109819,
#  110397,
#  107726,
#  110738,
#  106932,
#  107413,
#  108770,
#  109801,
#  106831,
#  107163,
#  109578,
#  112569,
#  108967,
#  108151,
#  111189,
#  109877,
#  108814,
#  106325,
#  113338,
#  108284,
#  110447,
#  108415,
#  110758,
#  108104,
#  108206,
#  109365,
#  112721,
#  106431,
#  109203,
#  107467,
#  108607,
#  109683,
#  111231,
#  108208,
#  ...]

# %%
import math, re, sys, fnmatch, string
import pandas as pd
import unicodecsv as csv
import enchant
import os
reload(sys)
d = enchant.Dict("en_US")
negative = []
positive = []
neutral = []
compounded = []
total1=[]
rev_id=[]
subject=[]
alt_subject=[]
f = 'vader_sentiment_lexicon.txt' # empirically derived valence ratings for words, emoticons, slang, swear words, acronyms/initialisms

word_valence_dict = dict(map(lambda (w, m): (w, float(m)), [
            wmsr.strip().split('\t')[0:2] for wmsr in open(f) ]))

#except:
#    word_valence_dict = dict(map(lambda (w, m): (w, float(m)), [
#            wmsr.strip().split('        ')[0:2] for wmsr in open(f) ]))

# for removing punctuation
regex_remove_punctuation = re.compile('[%s]' % re.escape(string.punctuation))

def sentiment(text):
    """
    Returns a float for sentiment strength based on the input text.
    Positive values are positive valence, negative value are negative valence.
    """
    text = text.lower().replace('"','')
    test =text.split(' ')
    length = len(test)
    #print length
    for i in range (0,len(test)-1):
        if '/' in test[i]:
            test[i]=test[i].split('/')[0]

        if test[i] == "five" or test[i] == "one" or test[i] == "four" or test[i] == "three" or test[i] == "two" or test[i] == "5" or test[i] == "4" or test[i] == "3" or test[i] == "2" or test[i] == "1" or test[i] == "no" or test[i] == "open" :
            if test[i+1] =='star' or test[i+1] == 'stars' or test[i+1] == 'more'or test[i+1] == 'pack'or test[i+1] == 'packet'or test[i+1] == 'package':
                test[i]=test[i] + '-' + test[i+1]
                test [i+1]=''
        if test[i] == "stomach" or test[i] == "loose":
            if test[i+1] =='ace' or test[i+1] == 'motion':
                test[i]=test[i] + '-' + test[i+1]
                test [i+1]=''
        if test[i] == "use":
            if test[i+1] =='less' or test[i+1] == 'full' or test[i+1] == 'les' or test[i+1] == 'lss' or test[i+1] == 'ls':
                test[i]=test[i] + '-' + test[i+1]
                test [i+1]=''

        if test[i] == "die" :
            if test[i+1] =='to':
                test[i]=test[i] + '-' + test[i+1]
                if test[i+2]:
                    test[i]=test[i] + '-' + test[i+2]
                    test [i+2]=''
        try:
            if not d.check(test[i]):
                test[i]=d.suggest(test[i])[0]
        except:
            pass

    text = "  ".join(test)
    text = text.strip()
    wordsAndEmoticons = str(text).split() #doesn't separate words from adjacent punctuation (keeps emoticons & contractions)
#    print wordsAndEmoticons
    text_mod = text #regex_remove_punctuation.sub('', text) # removes punctuation (but loses emoticons & contractions)
 #   print text_mod
    wordsOnly = str(text_mod).split()
 #   print wordsOnly
    # get rid of empty items or single letter "words" like 'a' and 'I' from wordsOnly
    for word in wordsOnly:
        if len(word) <= 1:
            wordsOnly.remove(word)    
    # now remove adjacent & redundant punctuation from [wordsAndEmoticons] while keeping emoticons and contractions
    puncList = [".", "!", "?", ",", ";", ":", "-", "'", "\"", 
                "!!", "!!!", "??", "???", "?!?", "!?!", "?!?!", "!?!?"] 
    for word in wordsOnly:
        for p in puncList:
            pword = p + word
            x1 = wordsAndEmoticons.count(pword)
            while x1 > 0:
                i = wordsAndEmoticons.index(pword)
                wordsAndEmoticons.remove(pword)
                wordsAndEmoticons.insert(i, word)
                x1 = wordsAndEmoticons.count(pword)
            
            wordp = word + p
            x2 = wordsAndEmoticons.count(wordp)
            while x2 > 0:
                i = wordsAndEmoticons.index(wordp)
                wordsAndEmoticons.remove(wordp)
                wordsAndEmoticons.insert(i, word)
                x2 = wordsAndEmoticons.count(wordp)

    # get rid of residual empty items or single letter "words" like 'a' and 'I' from wordsAndEmoticons
    for word in wordsAndEmoticons:
        if len(word) <= 1:
            wordsAndEmoticons.remove(word)
    word_len= len(wordsAndEmoticons)
    #print wordsAndEmoticons   
    # remove stopwords from [wordsAndEmoticons]
    #stopwords = [str(word).strip() for word in open('stopwords.txt')]
    #for word in wordsAndEmoticons:
    #    if word in stopwords:
    #        wordsAndEmoticons.remove(word)
    
    # check for negation
    negate = ["aint", "arent", "cannot", "cant", "couldnt", "darent", "didnt", "doesnt",
              "ain't", "aren't", "can't", "couldn't", "daren't", "didn't", "doesn't",
              "dont", "hadnt", "hasnt", "havent", "isnt", "mightnt", "mustnt", "neither",
              "don't", "hadn't", "hasn't", "haven't", "isn't", "mightn't", "mustn't",
              "neednt", "needn't", "never", "none", "nope", "nor", "not","no", "nothing", "nowhere", 
              "oughtnt", "shant", "shouldnt", "uhuh", "wasnt", "werent",
              "oughtn't", "shan't", "shouldn't", "uh-uh", "wasn't", "weren't",  
              "without", "wont", "wouldnt", "won't", "wouldn't", "rarely", "seldom", "despite","less"]
    def negated(list, nWords=[], includeNT=True):
        nWords.extend(negate)
        #print list
        for word in nWords:
            if word in list:
                #print word
                return True
        if includeNT:
            for word in list:
                if "n't" in word:
                    return True
        if "least" in list:
            i = list.index("least")
            if i > 0 and list[i-1] != "at":
                return True
        return False
        
    def normalize(score, alpha=1):
        # normalize the score to be between -1 and 1 using an alpha that approximates the max expected value 
        normScore = score/math.sqrt( ((score*score) + alpha) )
        return normScore
    
    def wildCardMatch(patternWithWildcard, listOfStringsToMatchAgainst):
        listOfMatches = fnmatch.filter(listOfStringsToMatchAgainst, patternWithWildcard)
        return listOfMatches
        
    
    def isALLCAP_differential(wordList):
        countALLCAPS= 0
        for w in wordList:
            if str(w).isupper(): 
                countALLCAPS += 1
        cap_differential = len(wordList) - countALLCAPS
        if cap_differential > 0 and cap_differential < len(wordList):
            isDiff = True
        else: isDiff = False
        return isDiff
    isCap_diff = isALLCAP_differential(wordsAndEmoticons)
    
    b_incr = 0.293 #(empirically derived mean sentiment intensity rating increase for booster words)
    b_decr = -0.293
    # booster/dampener 'intensifiers' or 'degree adverbs' http://en.wiktionary.org/wiki/Category:English_degree_adverbs
    booster_dict = {"absolutely": b_incr, "amazingly": b_incr, "awfully": b_incr, "completely": b_incr, "considerably": b_incr, 
                    "decidedly": b_incr, "deeply": b_incr, "effing": b_incr, "enormously": b_incr, 
                    "entirely": b_incr, "especially": b_incr, "exceptionally": b_incr, "extremely": b_incr,
                    "fabulously": b_incr, "flipping": b_incr, "flippin": b_incr, 
                    "fricking": b_incr, "frickin": b_incr, "frigging": b_incr, "friggin": b_incr, "fully": b_incr, "fucking": b_incr, 
                    "greatly": b_incr, "hella": b_incr, "highly": b_incr, "hugely": b_incr, "incredibly": b_incr, 
                    "intensely": b_incr, "majorly": b_incr, "more": b_incr, "most": b_incr, "must": b_incr, "particularly": b_incr, 
                    "purely": b_incr,"please": b_incr, "quite": b_incr, "really": b_incr, "remarkably": b_incr, 
                    "so": b_incr,  "substantially": b_incr, "damn": b_incr, 
                    "thoroughly": b_incr, "totally": b_incr, "tremendously": b_incr, 
                    "uber": b_incr, "unbelievably": b_incr, "unusually": b_incr, "utterly": b_incr, 
                    "very": b_incr,"big":b_incr,"help":b_incr,"heck":b_incr,"too":b_incr,"lots":b_incr,"atall":b_incr,
                    
                    "almost": b_decr, "barely": b_decr, "hardly": b_decr, "just enough": b_decr, 
                    "kind of": b_decr, "kinda": b_decr, "kindof": b_decr, "kind-of": b_decr,
                    "less": b_decr, "little": b_decr, "marginally": b_decr, "occasionally": b_decr, "partly": b_decr, 
                    "scarcely": b_decr, "slightly": b_decr, "somewhat": b_decr, 
                    "sort of": b_decr, "sorta": b_decr, "sortof": b_decr, "sort-of": b_decr,"rip": b_decr}
    sentiments = []
 #   print wordsAndEmoticons
    for item in wordsAndEmoticons:
       # print (item)
        v = 0
        i = wordsAndEmoticons.index(item)
        if (i < len(wordsAndEmoticons)-1 and str(item).lower() == "kind" and \
           str(wordsAndEmoticons[i+1]).lower() == "of") or str(item).lower() in booster_dict:
            sentiments.append(v)
            continue
        item_lowercase = str(item).lower()
        
        if  item_lowercase in word_valence_dict:
           # print ("item in valence lexion file--->",item_lowercase)
            v = float(word_valence_dict[item_lowercase])
            #print ("val", v)
            c_incr = 0.733 #(empirically derived mean sentiment intensity rating increase for using ALLCAPs to emphasize a word)
            if str(item).isupper() and isCap_diff:
                if v > 0: v += c_incr
                else: v -= c_incr
            def scalar_inc_dec(word, valence):
                scalar = 0.0
                
                word_lower = str(word).lower()
                if word_lower in booster_dict:
                    #print ("words in scalar-->",word_lower)
                    scalar = booster_dict[word_lower]
                    if valence < 0: scalar *= -1
                    if str(word).isupper() and isCap_diff:
                        if valence > 0: scalar += c_incr
                        else:  scalar -= c_incr
 #               print ("scal-->",scalar) 
                return scalar
            n_scalar = -1.0
            if (i+1)<word_len:
                if str(wordsAndEmoticons[i+1]).lower() in word_valence_dict and negated([wordsAndEmoticons[i]]) :
                    print ("insde")

            #print ("previous-->",wordsAndEmoticons[i-1])                               
            try:
                if i > 0 and str(wordsAndEmoticons[i-1]).lower() not in word_valence_dict and (i+1)<=word_len:
                    s1 = scalar_inc_dec(wordsAndEmoticons[i-1], v)
                    v = v+s1
                    
                    if negated([wordsAndEmoticons[i-1]]):
                        
                        v = v*n_scalar
                        #print ("insie",v)
                
            except:
                if i > 0 and str(wordsAndEmoticons[i-1]).lower() not in word_valence_dict and (i+1)<word_len:
                    s1 = scalar_inc_dec(wordsAndEmoticons[i-1], v)
                    v = v+s1
                    
                    if negated([wordsAndEmoticons[i-1]]):
                        v = v*n_scalar
                    #print ("inside 2",v)
                
            if i > 1 and str(wordsAndEmoticons[i-2]).lower() not in word_valence_dict and (i+1)<=word_len:
                s2 = scalar_inc_dec(wordsAndEmoticons[i-2], v)
                if s2 != 0: s2 = s2*0.95
                v = v+s2
                if wordsAndEmoticons[i-2] == "never" and (wordsAndEmoticons[i-1] == "so" or wordsAndEmoticons[i-1] == "this"): 
                    v = v*1.5                    
                
                elif negated([wordsAndEmoticons[i-2]]):
                    v = v*n_scalar
            if i > 2 and str(wordsAndEmoticons[i-3]).lower() not in word_valence_dict and (i+1)<word_len:
                s3 = scalar_inc_dec(wordsAndEmoticons[i-3], v)
                if s3 != 0: s3 = s3*0.9
                v = v+s3
                if wordsAndEmoticons[i-3] == "never" and \
                   (wordsAndEmoticons[i-2] == "so" or wordsAndEmoticons[i-2] == "this") or \
                   (wordsAndEmoticons[i-1] == "so" or wordsAndEmoticons[i-1] == "this"):
                    v = v*1.25
                elif negated([wordsAndEmoticons[i-3]]): v = v*n_scalar
                
                # check for special case idioms using a sentiment-laden keyword known to SAGE
                special_case_idioms = {"the shit": 3, "the bomb": 3, "bad ass": 1.5, "yeah right": -2, 
                                       "cut the mustard": 2, "kiss of death": -1.5, "hand to mouth": -2}
                # future work: consider other sentiment-laden idioms
                #other_idioms = {"back handed": -2, "blow smoke": -2, "blowing smoke": -2, "upper hand": 1, "break a leg": 2, 
                #                "cooking with gas": 2, "in the black": 2, "in the red": -2, "on the ball": 2,"under the weather": -2}
                onezero = "{} {}".format(str(wordsAndEmoticons[i-1]), str(wordsAndEmoticons[i]))
                twoonezero = "{} {}".format(str(wordsAndEmoticons[i-2]), str(wordsAndEmoticons[i-1]), str(wordsAndEmoticons[i]))
                twoone = "{} {}".format(str(wordsAndEmoticons[i-2]), str(wordsAndEmoticons[i-1]))
                threetwoone = "{} {} {}".format(str(wordsAndEmoticons[i-3]), str(wordsAndEmoticons[i-2]), str(wordsAndEmoticons[i-1]))
                threetwo = "{} {}".format(str(wordsAndEmoticons[i-3]), str(wordsAndEmoticons[i-2]))                    
                if onezero in special_case_idioms: v = special_case_idioms[onezero]
                elif twoonezero in special_case_idioms: v = special_case_idioms[twoonezero]
                elif twoone in special_case_idioms: v = special_case_idioms[twoone]
                elif threetwoone in special_case_idioms: v = special_case_idioms[threetwoone]
                elif threetwo in special_case_idioms: v = special_case_idioms[threetwo]
                if len(wordsAndEmoticons)-1 > i:
                    zeroone = "{} {}".format(str(wordsAndEmoticons[i]), str(wordsAndEmoticons[i+1]))
                    if zeroone in special_case_idioms: v = special_case_idioms[zeroone]
                if len(wordsAndEmoticons)-1 > i+1:
                    zeroonetwo = "{} {}".format(str(wordsAndEmoticons[i]), str(wordsAndEmoticons[i+1]), str(wordsAndEmoticons[i+2]))
                    if zeroonetwo in special_case_idioms: v = special_case_idioms[zeroonetwo]
                
                # check for booster/dampener bi-grams such as 'sort of' or 'kind of'
                if threetwo in booster_dict or twoone in booster_dict:
                    v = v+b_decr
            
            # check for negation case using "least"
            if i > 1 and str(wordsAndEmoticons[i-1]).lower() not in word_valence_dict \
                and str(wordsAndEmoticons[i-1]).lower() == "least" and (i+1)<word_len:
                if (str(wordsAndEmoticons[i-2]).lower() != "at" and str(wordsAndEmoticons[i-2]).lower() != "very") :
                    v = v*n_scalar
            elif i > 0 and str(wordsAndEmoticons[i-1]).lower() not in word_valence_dict \
                and str(wordsAndEmoticons[i-1]).lower() == "least" and (i+1)<word_len:
                v = v*n_scalar
       # print (v)
        sentiments.append(v) 
            
    # check for modification in sentiment due to contrastive conjunction 'but'
    if 'but' in wordsAndEmoticons or 'BUT' in wordsAndEmoticons:#
        try: bi = wordsAndEmoticons.index('but')
        except: bi = wordsAndEmoticons.index('BUT')
        for s in sentiments:
            si = sentiments.index(s)
            if si <bi :
                sentiments.pop(si)
                sentiments.insert(si, s*0.8)
            elif si>bi :
                #print ("si-->",si)
                sentiments.pop(si)
                sentiments.insert(si, s*1.2)
    if 'request' in wordsAndEmoticons or 'REQUEST' in wordsAndEmoticons:#
        try: bi = wordsAndEmoticons.index('request')
        except: bi = wordsAndEmoticons.index('request')
        for s in sentiments:
            si = sentiments.index(s)
            if si <bi :
                sentiments.pop(si)
                sentiments.insert(si, s*1.8)
    
               
 #       print ("sent-->",sentiments)
                
    if sentiments:
        
        sum_s = float(sum(sentiments))
        #print sentiments, sum_s
        
        # check for added emphasis resulting from exclamation points (up to 4 of them)
        ep_count = str(text).count("!")
        if ep_count > 4: ep_count = 4
        ep_amplifier = ep_count*0.292 #(empirically derived mean sentiment intensity rating increase for exclamation points)
        if sum_s > 0:  sum_s += ep_amplifier
        elif  sum_s < 0: sum_s -= ep_amplifier
        
        # check for added emphasis resulting from question marks (2 or 3+)
        qm_count = str(text).count("?")
        qm_amplifier = 0
        if qm_count > 1:
            if qm_count <= 3: qm_amplifier = qm_count*0.18
            else: qm_amplifier = 0.96
            if sum_s > 0:  sum_s += qm_amplifier
            elif  sum_s < 0: sum_s -= qm_amplifier
       # print (sum_s)
        compound = normalize(sum_s)
        #print (compound)
        # want separate positive versus negative sentiment scores
        pos_sum = 0.0
        neg_sum = 0.0
        neu_count = 0
        total = 1
        tot = 0
        for sentiment_score in sentiments:
            if sentiment_score > 0:
                pos_sum += (float(sentiment_score) +1) # compensates for neutral words that are counted as 1
            if sentiment_score < 0:
                neg_sum += (float(sentiment_score) -1) # when used with math.fabs(), compensates for neutrals
            if sentiment_score == 0:
                neu_count += 1
        
        if pos_sum > math.fabs(neg_sum): pos_sum += (ep_amplifier+qm_amplifier)
        elif pos_sum < math.fabs(neg_sum): neg_sum -= (ep_amplifier+qm_amplifier)

        neu_count=normalize(neu_count)
        total = (math.fabs(pos_sum) + math.fabs(neg_sum))
        if total == 0 :
            total = 1
#        print pos_sum ," ",neg_sum
        pos = (math.fabs(pos_sum / total))
        neg = (math.fabs(neg_sum / total))
        neu = normalize((neu_count/total))
    else:
        compound = 0.0; pos = 0.0; neg = 0.0; neu = 0.0
#    print neg
    tot = pos+(-1)*neg+neu

        
    s = {"neg" : round(neg, 3), 
         "neu" : round(neu, 3),
         "pos" : round(pos, 3),
         "compound" : round(compound, 4),
         "total" : round(tot,3)}

    return s


def vader(x):
    #print type(str(x))
   # row = list(x)
    try:
        x=x.encode('utf-8')
        sentence = str(x).encode('ascii','ignore').decode('ascii')
        i=0
        temp_p=0
        temp_n=0
        temp_c=0
        lines_list = re.split(r'[.!?]+', str(sentence))
        for sent in lines_list:
            sent=sent.strip().lower()
            if sent == '':
                print ("empty")
                continue
            else:
                #print sent
                ss = sentiment(sent)
                #print (ss)
                if not all(value == 0 for value in ss.values()):
                    i=i+1
                temp_p=temp_p+ss['pos']
                temp_n=temp_n+ss['neg']
                temp_c=temp_c+ss['compound']
        #print ("i -->",i)
       # print temp_c
        #print i
        if i==0:
            i=1
        if len(str(sentence).split(" ")) <4:
            i=i*2
        tc=float(temp_c/float(i))*100
        tp=float(temp_p/float(i))*100
        tn = float(temp_n/float(i))*100
    except:
        tc = 0
    return tc

# %%
review_file['confidence_score'] = review_file.review_text.apply(lambda row: vader(row))

# %%
import os
import re
from gensim.utils import to_unicode, smart_open, dict_from_corpus
import pandas as pd
import logging
import argparse
from collections import namedtuple
from gensim.utils import smart_open, to_utf8, tokenize
from nltk.tokenize import word_tokenize
import math
import random

def dict_of_phrases(phrase_dir):
    phrase_dict = dict()
    global_dict = dict()


    # Making a dict() for all the phrases we have
    # and ensure that the phrases don't have underscores in them

    for DIR in os.listdir(phrase_dir):
        phrase_dict[DIR] = dict()
        if DIR.startswith("."):
            continue
        for infile in os.listdir(os.path.join(phrase_dir, DIR)):
            if infile.startswith("."):
                continue
            if infile.endswith(".txt") :
                fname = infile.split(".txt")[0]
                phrase_dict[DIR][fname] = []

                # reading the phrases in file
                with open(phrase_dir + "/" + DIR + "/" + infile, 'rb') as foo:



                    line_num = 0
                    for line in foo:
                        if "\r" in line:
                            linee = line.split("\r")
                            for line in linee:
                                line_num += 1

                                # Replacing underscores with spaces
                                line = line.decode('ascii', 'ignore').replace("_", " ").replace("\n\r", "\n")

                                # Replacing dashes with spaces so as to prevent errors
                                # in detecting word boundaries
                                line = line.replace("-", " ")
                                phrase = line.strip().split("|")[0]

                                # check for empty line
                                if phrase == "":
                                    continue

                                if phrase not in phrase_dict:
                                    phrase_dict[DIR][fname].append(phrase)
                                    global_dict[phrase] \
                                        = 1
                        else:
                            line_num += 1

                            # Replacing underscores with spaces
                            line = line.decode('ascii','ignore').replace("_", " ").replace("\n\r","\n")

                            # Replacing dashes with spaces so as to prevent errors
                            # in detecting word boundaries
                            line = line.replace("-", " ")
                            phrase = line.strip().split("|")[0]

                            # check for empty line
                            if phrase == "":
                                #print line_num
                                continue
                                
                            if phrase not in phrase_dict:
                                phrase_dict[DIR][fname].append(phrase)


                                global_dict[phrase] = 1
                                    
    return phrase_dict, global_dict

def load_negation_words(negation_words_file):
    """ reads negation words from the "negation.sorted.txt file"
    :param negation_words_file: file containing words which induce negation
    :return: list of negation words
    """
    #neg_words_file = os.path.join(negation_words_dir, "negation.sorted.txt")

    # reading the entire file using readlines()
    neg_words_list = smart_open(negation_words_file, mode='rb').readlines()

    # striping the "/n" at the end of every line
    neg_words_list = list(word.strip() for word in neg_words_list)
    return neg_words_list

def check_super_phrase(phrase_list, phrase_dict, window=16):
    """the phrases are in lowercase,
    We will iterate through phrases in the phrase_list and see
    if there is any sub-phrase in the phrase_dict after deleting
    the current phrase .It will store the new super phrases
    We will remove sub phrases if they are found

    :param phrase_list: list of valid phrases found in line
    :param phrase_dict: copy of the above list in dict form
    :param window: size of window to be considered
    :return: list of valid super phrases
    """

    new_phrase_dict = phrase_dict.copy()

    for num_phr, phrase in enumerate(phrase_list):

        # flag variable checks for the presence of sub-phrase
        temp_phrase_dict = phrase_dict.copy()

        # deletes the current phrase from the dictionary
        del temp_phrase_dict[phrase]

        # tokenizes the current phrase with "whitespace" separator
        toks = phrase.split(" ")

        # Iterates through the toks to check for presence of sub-phrase
        # Here we will have to iterate through the toks[0:] since we also
        # need to find unigrams
        for i, start_token in enumerate(toks[0:]):

            # Since we will be having uni-grams in curated phrases,
            # the arguments to range function will be given as range(0, window)
            for j in range(0, window):
                if i + j + 1 <= len(toks):
                    new_string = " ".join(toks[i:i + j + 1])
                    if new_string in temp_phrase_dict:
                        if new_string in new_phrase_dict:
                            del new_phrase_dict[new_string]

    return new_phrase_dict

# %%
path = os.getcwd()
phrase_dir = path+"/Pedigree_autoresponses/fine_grained_phrases_pedigree_sentiment_sub_clusters_old/"
replies_dir = path+"/Pedigree_autoresponses/responses_sub_clusters/"
negation_words_file = "/Users/devanshg/Desktop/enixta-machine-learning-master/Smaartpulse_Python_Base/data_annotation/negation_words.txt"
phrase_dict, global_dict = dict_of_phrases(phrase_dir=phrase_dir)
del phrase_dict['.DS_Store']
#negation_words_list = load_negation_words(negation_words_file= negation_words_file)
replies_dict, global_replies_dict = dict_of_phrases(replies_dir)
questions_file = open( "Pedigree_autoresponses/hot_warm_dont_reply_classification/questions_words.txt", 'r')
next_4 = questions_file.readline()

questions_list = []
while next_4 != "": 
    questions_list.append(next_4.strip())
    next_4 = questions_file.readline()

#reliability_list = reliability_list[0].split('\r')
question_words = []
for z in questions_list:
    z_list = z.split('\r')
    question_words = question_words + z_list

aspects_location = path+'/Pedigree_autoresponses/hot_warm_dont_reply_classification/'

dont_reply_file = open(aspects_location + "dont-reply.txt", 'r')
next_2 = dont_reply_file.readline()

dont_reply_list = []
while next_2 != "": 
    dont_reply_list.append(next_2.strip())
    next_2 = dont_reply_file.readline()

dont_reply_clusters =[words for segments in dont_reply_list for words in segments.replace('\n','').split('\r')]
dont_reply_clusters = filter(None, dont_reply_clusters)
dont_reply_aspects = []

# %%
for file in glob.glob('Pedigree_autoresponses/fine_grained_phrases_pedigree_sentiment_sub_clusters_old/aspects/*'):
    t =file.replace('Pedigree_autoresponses/fine_grained_phrases_pedigree_sentiment_sub_clusters_old/aspects/','')
    t = t.replace('.txt','')
    if t in dont_reply_clusters:
        f = open(file,'r+')
        dont_reply_aspects.append(f.readlines())
dont_reply_aspects=list(chain.from_iterable(dont_reply_aspects))
dont_reply_aspects=[i.replace('\n','').split('\r', 1)[0] for i in dont_reply_aspects]
dont_reply_aspects= filter(None, dont_reply_aspects)

# %%
from nltk.tokenize import word_tokenize
from nltk.util import ngrams

def get_ngrams(text ):
    list1 =[]
    for i in range(1,len(text.split(' '))):
        n_grams = ngrams(word_tokenize(text), i)
        list1.append([ ' '.join(grams) for grams in n_grams])
    list1=list(chain.from_iterable(list1))
    return list1

# %%
#def aspect_finder():
aspect_out =[]
for row in review_file.to_dict('records'):
    rcs = 100.0
    dead = ['died','death','dying','hospit','killed','ill']
    aspect = []
    aspect_keyword = []
    flag =0
    #try:
    temp_text = row['review_text'].encode('ascii','ignore')
    text = str(temp_text).lower()
    txt =get_ngrams(text)
    ques = set(txt)&set(question_words) 
    ques = sorted(ques, key = lambda k : txt.index(k))
    if any(ques):
        flag =1
        math.ceil(random.uniform(78.4, 85.9)*100)/100
    die = set(txt)&set(dead) 
    die = sorted(die, key = lambda k : txt.index(k))
    if any(die):
        flag =2
        rcs = math.ceil(random.uniform(95.4, 99.9)*100)/100
        

    for file in glob.glob('Pedigree_autoresponses/fine_grained_phrases_pedigree_sentiment_sub_clusters_old/aspects/*'):
        t =file.replace('Pedigree_autoresponses/fine_grained_phrases_pedigree_sentiment_sub_clusters_old/aspects/','')
        t = t.replace('.txt','')
        f = open(file,'r+')
        keyword = f.readlines()
        keyword =[i.replace('\n','').split('\r', 1)[0] for i in keyword]
        list1 = set(keyword)&set(txt) 
        list2 = sorted(list1, key = lambda k : txt.index(k))
        #if re.search(r'\bgood\b','A good product, loved by my pet.'):
            #print('correct')
        if any(list2) :
            aspect.append(t)
            aspect_keyword.append(list2)
    aspect_keyword=list(chain.from_iterable(aspect_keyword))
    aspect_keyword=[i.replace('\n','').split('\r', 1)[0] for i in aspect_keyword]
    match = set(aspect_keyword)&set(dont_reply_aspects) 
    match = sorted(match, key = lambda k : aspect_keyword.index(k))
    print match
    if any(match):
        rcs = float(rcs - float(len(match)*.65))
        if len(match) == len(aspect_keyword):
            aspect.append('dont_reply')
            flag = 3
            rcs = 0.0
#     except:
#         aspect =['Unicode error']
#         aspect_keyword =['error']
        #return aspect,aspect_keyword
    if len(temp_text) < 80 and len(aspect_keyword) < 1:
        #aspects_missed = expected - actual
        aspects_missed = 1 - len(aspect_keyword)
    elif len(temp_text) >= 80 and len(temp_text)< 180 and len(aspect_keyword) < 2:
        aspects_missed = 2 - len(aspect_keyword)
    elif len(temp_text) >= 180 and len(temp_text) < 450 and len(aspect_keyword) < 3:
        aspects_missed = 3 - len(aspect_keyword)
    elif len(temp_text) >= 450 and len(aspect_keyword) < 4:
        aspects_missed = 4 - len(aspect_keyword)
    else:
        aspects_missed = 0
    rcs = rcs - 4*aspects_missed*.5
    if row['reviewer_name'] == 'Pedigree Expert':
        rcs=0
    row['aspect']=aspect
    row['aspect_keyword'] = aspect_keyword
    row['flag'] = flag
    score = row['confidence_score']
    if int(score) <= 0:
        row['polarity'] = 'negative'
    if int(score) > 0:
        row['polarity'] = 'positive'
    if int(flag) == 1:
        row['polarity'] = 'neutral'
    row['response_confidence_score'] = rcs
    aspect_out.append(row)

# %%
aspect_out=pd.DataFrame(aspect_out)
# aspect_out.to_csv("intermediate.csv",quoting=csv.QUOTE_ALL,encoding='utf8')
#aspect_out.dropna(subset=['review_text'],inplace=True)

#aspect_out[aspect_out.flag ==2]

# %%
def replier(x):
    row = dict(x)
    replies_hot = replies_dict[replies_dict.aspect == 'hot-clusters']
    replies_overall = replies_dict[replies_dict.aspect == 'product-overall-5stars']
    conf_score = row['confidence_score']
    review_text = row['review_text']
    try:
        reviewer_name = str(row['reviewer_name'])
        print reviewer_name
        reviewer_name = str(reviewer_name).encode('utf-8').encode('ascii','ignore').decode('ascii')
    except:
        reviewer_name = 'Customer'
    star_rating = row['star_rating']
    flag = row['flag']
    if conf_score < 0:
        if flag == 0 or flag =='3':
            reply = "Dear "+ str(reviewer_name)
            reply = reply +', '+random.choice(list(replies_hot.template_response))
        if flag == 2:
            reply = "Dear "+reviewer_name+", We are deeply saddened to hear about your dog. We request you to share your contact details so that we can assist you ASAP on our toll free number 1800-4071-12121 or write to us at pedigree.india@effem.com. Regards Team Pedigree."

    else:
        reply = reply = reply +', '+random.choice(list(replies_overall.template_response))
        if "customer name" in reply:
            reply=reply.replace('customer name',str(reviewer_name))
        else:
            x = "Dear "+ str(reviewer_name)
            reply = x +', '+reply
    if flag == 1:
        reply = "Dear "+reviewer_name+", for any queries and facts regarding your dog/cat please refer to the FAQs on our officil site https://www.pedigree.com/faqs. Please feel free to reach us on our toll free number 1800-4071-12121 or write to us at pedigree.india@effem.com for any further assistance. Regards Team Pedigree."
    if row['reviewer_name'] == 'Pedigree Expert':
        reply = ""
    

    return reply

# %%
#df = aspect_out[['aspect','id','source_review_id','polarity']]
# df = aspect_out[aspect_out.source_review_id == 'R1BPUSEVELFI83']
# df['response'] = df.apply(lambda row: replier(row), axis = 1)
# list(df.response.str.split(' '))

# %%
aspect_out['response'] = aspect_out.apply(lambda row: replier(row), axis = 1)
aspect_out = aspect_out.dropna(subset=['response'],inplace=True)
aspect_out.to_csv('responses_mars_pedigree_10th_may_2018_all_headers_old_aspects.txt',sep='~',quoting=csv.QUOTE_ALL,index=False,encoding='utf-8')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-12e35ff86299> in <module>()
#       1 aspect_out['response'] = aspect_out.apply(lambda row: replier(row), axis = 1)
#       2 aspect_out = aspect_out.dropna(subset=['response'],inplace=True)
# ----> 3 aspect_out.to_csv('responses_mars_pedigree_10th_may_2018_all_headers_old_aspects.txt',sep='~',quoting=csv.QUOTE_ALL,index=False,encoding='utf-8')
#
# AttributeError: 'NoneType' object has no attribute 'to_csv'

# %%
final_resp = aspect_out
aspect_out['response_2'] = ""
aspect_out['response_3'] = ""
aspect_out['degree'] = ""
# del final_resp['aspect']
# del final_resp['aspect_keyword']
# del final_resp['flag']
final_resp.id = final_resp.id.astype(int)
cols = ['id','source_review_id','response','response_2','response_3','confidence_score','polarity','degree','response_confidence_score']

final_resp = final_resp[cols]
final_resp.to_csv('responses_mars_pedigree_10th_may_2018_final_old_aspects.txt',sep='~',quoting=csv.QUOTE_ALL,index=False,encoding='utf-8')

# %%
#aspect_out[aspect_out.review_text.str.contains('expir')
insight = pd.read_csv('responses_mars_pedigree_25th_april_2018_all_headers.txt',sep='~',quoting=csv.QUOTE_ALL,encoding='utf-8')

# %%
dog_breed = insight[insight.aspect.str.contains('dog-user')]

# %%
dog_breed['aspect']=(dog_breed['aspect']).astype(str).str.replace('[','').astype(str).str.replace(']','').astype(str).str.split(',')
dog_breed['aspect_keyword']=(dog_breed['aspect_keyword']).astype(str).str.replace('[','').astype(str).str.replace(']','').astype(str).str.split(',')

# %%
list(dog_breed['aspect'])
# Out:
# [['dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['convienience', ' dog-user-breed'],
#  ['all',
#   ' condition_of_product',
#   ' convienience',
#   ' dog-user-breed',
#   ' smell'],
#  ['convienience', ' delivery', ' dog-user-breed', ' pricing'],
#  ['dog-user-breed', ' information', ' pricing'],
#  ['all',
#   ' convienience',
#   ' dog-user-breed',
#   ' health_impact',
#   ' nutrition_ingredientst',
#   ' pricing',
#   ' taste'],
#  ['all', ' dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['dog-user-breed', ' nutrition_ingredientst'],
#  ['all', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed', ' information', ' pricing'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed', ' nutrition_ingredientst'],
#  ['all',
#   ' dog-user-breed',
#   ' information',
#   ' nutrition_ingredientst',
#   ' taste'],
#  ['all', ' dog-user-breed', ' nutrition_ingredientst'],
#  ['all', ' dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['convienience', ' dog-user-breed'],
#  ['dog-user-breed', ' nutrition_ingredientst', ' sizing', ' smell'],
#  ['all', ' dog-user-breed', ' pricing'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed', ' information', ' nutrition_ingredientst'],
#  ['all', ' condition_of_product', ' dog-user-breed'],
#  ['all', ' dog-user-breed', ' pricing'],
#  ['dog-user-breed'],
#  ['convienience', ' dog-user-breed', ' information'],
#  ['dog-user-breed'],
#  ['all', ' convienience', ' dog-user-breed'],
#  ['dog-user-breed', ' nutrition_ingredientst', ' pricing'],
#  ['condition_of_product', ' dog-user-breed'],
#  ['all',
#   ' convienience',
#   ' dog-user-breed',
#   ' information',
#   ' nutrition_ingredientst',
#   ' pricing',
#   ' sizing'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed', ' offers_n_discounts', ' pricing'],
#  ['dog-user-breed'],
#  ['all', ' convienience', ' dog-user-breed'],
#  ['all', ' dog-user-breed', ' nutrition_ingredientst'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed', ' nutrition_ingredientst'],
#  ['dog-user-breed'],
#  ['dog-user-breed', ' pricing'],
#  ['all', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['all',
#   ' condition_of_product',
#   ' convienience',
#   ' dog-user-breed',
#   ' information',
#   ' pricing'],
#  ['all', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' delivery', ' dog-user-breed', ' information', ' pricing', ' taste'],
#  ['all', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['dog-user-breed', ' nutrition_ingredientst'],
#  ['all', ' dog-user-breed', ' taste'],
#  ['all', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['all',
#   ' condition_of_product',
#   ' convienience',
#   ' dog-user-breed',
#   ' nutrition_ingredientst',
#   ' pricing',
#   ' sizing',
#   ' smell',
#   ' taste'],
#  ['all', ' dog-user-breed'],
#  ['dog-user-breed', ' pricing'],
#  ['all', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed', ' shelf_life'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed', ' nutrition_ingredientst'],
#  ['all',
#   ' delivery',
#   ' dog-user-breed',
#   ' nutrition_ingredientst',
#   ' offers_n_discounts',
#   ' pricing',
#   ' sizing'],
#  ['dog-user-breed'],
#  ['dog-user-breed', ' taste'],
#  ['all',
#   ' dog-user-breed',
#   ' information',
#   ' nutrition_ingredientst',
#   ' pricing'],
#  ['convienience', ' dog-user-breed', ' information'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed', ' nutrition_ingredientst'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['all', ' dog-user-breed', ' health_impact'],
#  ['dog-user-breed', ' health_impact', ' smell'],
#  ['dog-user-breed', ' smell'],
#  ['all', ' condition_of_product', ' convienience', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed', ' nutrition_ingredientst'],
#  ['all', ' dog-user-breed', ' nutrition_ingredientst', ' pricing'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed', ' nutrition_ingredientst', ' pricing'],
#  ['all',
#   ' delivery',
#   ' dog-user-breed',
#   ' health_impact',
#   ' information',
#   ' nutrition_ingredientst',
#   ' smell',
#   ' taste'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed', ' offers_n_discounts', ' shelf_life'],
#  ['all', ' dog-user-breed'],
#  ['all', ' convienience', ' dog-user-breed'],
#  ['all', ' dog-user-breed', ' pricing'],
#  ['dog-user-breed'],
#  ['all', ' convienience', ' dog-user-breed', ' information', ' pricing'],
#  ['dog-user-breed', ' nutrition_ingredientst'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['all',
#   ' convienience',
#   ' dog-user-breed',
#   ' health_impact',
#   ' nutrition_ingredientst'],
#  ['all', ' dog-user-breed', ' health_impact', ' pricing'],
#  ['all', ' convienience', ' dog-user-breed'],
#  ['convienience', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed', ' pricing'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed', ' nutrition_ingredientst', ' taste'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed', ' nutrition_ingredientst', ' pricing'],
#  ['all', ' dog-user-breed'],
#  ['all', ' delivery', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' condition_of_product', ' dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['dog-user-breed', ' nutrition_ingredientst'],
#  ['dog-user-breed'],
#  ['dog-user-breed', ' health_impact'],
#  ['all', ' dog-user-breed', ' health_impact'],
#  ['all', ' dog-user-breed'],
#  ['condition_of_product',
#   ' convienience',
#   ' dog-user-breed',
#   ' nutrition_ingredientst'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed', ' pricing'],
#  ['all', ' delivery', ' dog-user-breed', ' information', ' smell'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['all',
#   ' delivery',
#   ' dog-user-breed',
#   ' health_impact',
#   ' nutrition_ingredientst'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['condition_of_product', ' dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['all', ' appearance', ' dog-user-breed', ' health_impact'],
#  ['dog-user-breed'],
#  ['convienience', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['all', ' dog-user-breed', ' sizing'],
#  ['all', ' convienience', ' dog-user-breed', ' pricing'],
#  ['dog-user-breed', ' smell'],
#  ['condition_of_product',
#   ' convienience',
#   ' dog-user-breed',
#   ' information',
#   ' pricing',
#   ' sizing',
#   ' taste'],
#  ['all', ' convienience', ' dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['convienience', ' delivery', ' dog-user-breed', ' pricing'],
#  ['convienience', ' dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['all',
#   ' convienience',
#   ' delivery',
#   ' dog-user-breed',
#   ' information',
#   ' shelf_life'],
#  ['all', ' dog-user-breed'],
#  ['all', ' convienience', ' dog-user-breed'],
#  ['all', ' convienience', ' dog-user-breed', ' nutrition_ingredientst'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed', ' taste'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed', ' nutrition_ingredientst', ' sizing'],
#  ['convienience', ' dog-user-breed'],
#  ['dog-user-breed', ' nutrition_ingredientst'],
#  ['dog-user-breed', ' information'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed', ' offers_n_discounts'],
#  ['dog-user-breed', ' smell'],
#  ['all', ' convienience', ' dog-user-breed', ' pricing'],
#  ['all', ' dog-user-breed', ' health_impact'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed', ' nutrition_ingredientst', ' pricing'],
#  ['all', ' dog-user-breed', ' taste'],
#  ['convienience', ' dog-user-breed', ' nutrition_ingredientst', ' sizing'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['all', ' convienience', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['all',
#   ' convienience',
#   ' delivery',
#   ' dog-user-breed',
#   ' information',
#   ' offers_n_discounts',
#   ' pricing'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['all', ' dog-user-breed', ' pricing'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' convienience', ' dog-user-breed'],
#  ['all',
#   ' dog-user-breed',
#   ' health_impact',
#   ' information',
#   ' nutrition_ingredientst',
#   ' smell',
#   ' taste'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' convienience', ' dog-user-breed', ' pricing'],
#  ['all', ' dog-user-breed'],
#  ['dog-user-breed', ' sizing', ' smell'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['all',
#   ' convienience',
#   ' dog-user-breed',
#   ' nutrition_ingredientst',
#   ' pricing'],
#  ['all', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed', ' health_impact'],
#  ['dog-user-breed'],
#  ['all',
#   ' condition_of_product',
#   ' dog-user-breed',
#   ' nutrition_ingredientst'],
#  ['all', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed', ' health_impact', ' information', ' pricing'],
#  ['dog-user-breed'],
#  ['all', ' convienience', ' dog-user-breed', ' shelf_life', ' sizing'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['all',
#   ' condition_of_product',
#   ' convienience',
#   ' dog-user-breed',
#   ' health_impact',
#   ' nutrition_ingredientst',
#   ' pricing',
#   ' taste'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['all', ' convienience', ' dog-user-breed', ' nutrition_ingredientst'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['all',
#   ' dog-user-breed',
#   ' information',
#   ' nutrition_ingredientst',
#   ' pricing'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed', ' health_impact'],
#  ['all', ' convienience', ' dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['all', ' dog-user-breed', ' nutrition_ingredientst', ' taste'],
#  ['all', ' dog-user-breed', ' nutrition_ingredientst'],
#  ['all',
#   ' dog-user-breed',
#   ' health_impact',
#   ' nutrition_ingredientst',
#   ' pricing'],
#  ['all', ' dog-user-breed', ' nutrition_ingredientst'],
#  ['all', ' delivery', ' dog-user-breed', ' nutrition_ingredientst'],
#  ['appearance', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed', ' pricing'],
#  ['all', ' dog-user-breed'],
#  ['all', ' condition_of_product', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['condition_of_product', ' dog-user-breed'],
#  ['convienience', ' dog-user-breed', ' offers_n_discounts', ' pricing'],
#  ['dog-user-breed'],
#  ['all', ' delivery', ' dog-user-breed', ' pricing'],
#  ['all', ' dog-user-breed', ' pricing'],
#  ['all', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['all',
#   ' condition_of_product',
#   ' convienience',
#   ' dog-user-breed',
#   ' information',
#   ' nutrition_ingredientst',
#   ' pricing'],
#  ['dog-user-breed', ' health_impact'],
#  ['all',
#   ' convienience',
#   ' delivery',
#   ' dog-user-breed',
#   ' pricing',
#   ' sizing',
#   ' smell'],
#  ['condition_of_product', ' dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' convienience', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed', ' pricing'],
#  ['dog-user-breed'],
#  ['dog-user-breed', ' health_impact'],
#  ['all',
#   ' convienience',
#   ' dog-user-breed',
#   ' health_impact',
#   ' information',
#   ' pricing'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['convienience', ' dog-user-breed', ' nutrition_ingredientst'],
#  ['convienience',
#   ' dog-user-breed',
#   ' information',
#   ' offers_n_discounts',
#   ' pricing'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed', ' pricing'],
#  ['all', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed', ' health_impact', ' smell', ' taste'],
#  ['dog-user-breed', ' health_impact'],
#  ['dog-user-breed'],
#  ['all', ' convienience', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' appearance', ' dog-user-breed', ' nutrition_ingredientst'],
#  ['dog-user-breed', ' nutrition_ingredientst'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['all',
#   ' convienience',
#   ' dog-user-breed',
#   ' health_impact',
#   ' information',
#   ' pricing'],
#  ['all', ' dog-user-breed'],
#  ['all', ' delivery', ' dog-user-breed', ' pricing'],
#  ['appearance', ' convienience', ' dog-user-breed'],
#  ['all', ' delivery', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['delivery', ' dog-user-breed'],
#  ['all', ' condition_of_product', ' convienience', ' dog-user-breed'],
#  ['convienience', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed', ' health_impact', ' pricing'],
#  ['convienience',
#   ' dog-user-breed',
#   ' health_impact',
#   ' nutrition_ingredientst'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed', ' information'],
#  ['all', ' dog-user-breed', ' nutrition_ingredientst', ' smell'],
#  ['all', ' dog-user-breed'],
#  ['all', ' delivery', ' dog-user-breed', ' nutrition_ingredientst'],
#  ['all', ' dog-user-breed', ' offers_n_discounts', ' pricing'],
#  ['all', ' dog-user-breed', ' health_impact', ' nutrition_ingredientst'],
#  ['dog-user-breed', ' pricing'],
#  ['all', ' dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['all', ' condition_of_product', ' dog-user-breed', ' pricing'],
#  ['all', ' dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['all',
#   ' convienience',
#   ' dog-user-breed',
#   ' information',
#   ' pricing',
#   ' taste'],
#  ['dog-user-breed', ' nutrition_ingredientst', ' taste'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['convienience', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' appearance', ' convienience', ' dog-user-breed'],
#  ['dog-user-breed', ' smell'],
#  ['dog-user-breed'],
#  ['convienience', ' dog-user-breed'],
#  ['all',
#   ' convienience',
#   ' dog-user-breed',
#   ' nutrition_ingredientst',
#   ' sizing'],
#  ['dog-user-breed'],
#  ['all', ' convienience', ' delivery', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed', ' health_impact'],
#  ['all', ' convienience', ' dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['all', ' dog-user-breed', ' nutrition_ingredientst'],
#  ['all', ' dog-user-breed', ' taste'],
#  ['convienience', ' dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['all', ' delivery', ' dog-user-breed', ' taste'],
#  ['dog-user-breed'],
#  ['dog-user-breed', ' sizing'],
#  ['all', ' dog-user-breed', ' health_impact'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed', ' pricing'],
#  ['all', ' dog-user-breed', ' information'],
#  ['all', ' convienience', ' delivery', ' dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['dog-user-breed', ' smell'],
#  ['dog-user-breed', ' sizing'],
#  ['all', ' dog-user-breed', ' nutrition_ingredientst', ' sizing'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed', ' pricing'],
#  ['all', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed', ' health_impact'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed', ' nutrition_ingredientst'],
#  ['all', ' dog-user-breed'],
#  ['delivery', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['appearance', ' convienience', ' dog-user-breed', ' pricing'],
#  ['all', ' dog-user-breed'],
#  ['convienience', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed', ' nutrition_ingredientst', ' pricing'],
#  ['dog-user-breed', ' nutrition_ingredientst', ' taste'],
#  ['dog-user-breed'],
#  ['all', ' convienience', ' dog-user-breed', ' health_impact'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed', ' health_impact', ' pricing', ' smell'],
#  ['all', ' dog-user-breed', ' pricing'],
#  ['all', ' dog-user-breed'],
#  ['all', ' delivery', ' dog-user-breed'],
#  ['delivery', ' dog-user-breed', ' pricing'],
#  ['all', ' dog-user-breed', ' health_impact'],
#  ['all', ' convienience', ' dog-user-breed', ' pricing'],
#  ['all', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed', ' nutrition_ingredientst'],
#  ['all', ' dog-user-breed'],
#  ['all', ' delivery', ' dog-user-breed'],
#  ['all', ' convienience', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed', ' nutrition_ingredientst'],
#  ['dog-user-breed'],
#  ['dog-user-breed', ' health_impact', ' pricing'],
#  ['all',
#   ' condition_of_product',
#   ' dog-user-breed',
#   ' nutrition_ingredientst'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['dog-user-breed', ' pricing'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed', ' health_impact'],
#  ['condition_of_product',
#   ' convienience',
#   ' dog-user-breed',
#   ' nutrition_ingredientst',
#   ' sizing'],
#  ['dog-user-breed', ' smell'],
#  ['dog-user-breed',
#   ' health_impact',
#   ' information',
#   ' nutrition_ingredientst',
#   ' pricing'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['convienience', ' dog-user-breed', ' pricing'],
#  ['dog-user-breed', ' nutrition_ingredientst', ' taste'],
#  ['dog-user-breed'],
#  ['all',
#   ' convienience',
#   ' dog-user-breed',
#   ' health_impact',
#   ' information',
#   ' pricing'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['dog-user-breed', ' information', ' nutrition_ingredientst', ' pricing'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed', ' nutrition_ingredientst'],
#  ['dog-user-breed', ' nutrition_ingredientst'],
#  ['convienience', ' dog-user-breed', ' pricing'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed', ' pricing', ' taste'],
#  ['all', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed', ' nutrition_ingredientst'],
#  ['all',
#   ' condition_of_product',
#   ' dog-user-breed',
#   ' nutrition_ingredientst'],
#  ['dog-user-breed'],
#  ['all',
#   ' condition_of_product',
#   ' convienience',
#   ' dog-user-breed',
#   ' information',
#   ' nutrition_ingredientst',
#   ' offers_n_discounts',
#   ' pricing'],
#  ['dog-user-breed', ' health_impact', ' nutrition_ingredientst'],
#  ['all', ' dog-user-breed', ' health_impact'],
#  ['dog-user-breed', ' health_impact'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['convienience', ' dog-user-breed', ' pricing', ' shelf_life', ' taste'],
#  ['convienience', ' dog-user-breed', ' pricing'],
#  ['all', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' appearance', ' dog-user-breed'],
#  ['all', ' dog-user-breed', ' health_impact'],
#  ['dog-user-breed', ' pricing'],
#  ['convienience', ' dog-user-breed', ' taste'],
#  ['all', ' delivery', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed', ' nutrition_ingredientst'],
#  ['condition_of_product', ' dog-user-breed'],
#  ['convienience',
#   ' dog-user-breed',
#   ' information',
#   ' nutrition_ingredientst',
#   ' pricing'],
#  ['all', ' dog-user-breed'],
#  ['all', ' condition_of_product', ' convienience', ' dog-user-breed'],
#  ['all', ' dog-user-breed', ' information', ' pricing'],
#  ['dog-user-breed'],
#  ['convienience', ' dog-user-breed', ' health_impact'],
#  ['appearance', ' dog-user-breed'],
#  ['all', ' appearance', ' dog-user-breed'],
#  ['dog-user-breed', ' nutrition_ingredientst'],
#  ['all', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed', ' health_impact'],
#  ['dog-user-breed'],
#  ['all',
#   ' condition_of_product',
#   ' dog-user-breed',
#   ' nutrition_ingredientst',
#   ' smell'],
#  ['dog-user-breed', ' nutrition_ingredientst'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['all', ' dog-user-breed', ' health_impact'],
#  ['all', ' convienience', ' dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['convienience', ' dog-user-breed'],
#  ['dog-user-breed', ' health_impact'],
#  ['all', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['dog-user-breed', ' sizing'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed', ' pricing'],
#  ['all', ' dog-user-breed', ' pricing'],
#  ['dog-user-breed', ' pricing'],
#  ['all', ' dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['all',
#   ' condition_of_product',
#   ' dog-user-breed',
#   ' nutrition_ingredientst',
#   ' taste'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['convienience', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['dog-user-breed', ' taste'],
#  ['all', ' delivery', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed', ' nutrition_ingredientst'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['dog-user-breed', ' nutrition_ingredientst'],
#  ['dog-user-breed'],
#  ['delivery', ' dog-user-breed', ' pricing'],
#  ['condition_of_product', ' dog-user-breed', ' offers_n_discounts'],
#  ['all',
#   ' condition_of_product',
#   ' dog-user-breed',
#   ' nutrition_ingredientst',
#   ' sizing'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['convienience', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed', ' taste'],
#  ['all', ' dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['dog-user-breed', ' health_impact'],
#  ['all', ' delivery', ' dog-user-breed'],
#  ['condition_of_product', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' delivery', ' dog-user-breed', ' offers_n_discounts'],
#  ['dog-user-breed'],
#  ['convienience', ' delivery', ' dog-user-breed', ' offers_n_discounts'],
#  ['all', ' delivery', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' condition_of_product', ' dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['all', ' delivery', ' dog-user-breed', ' shelf_life'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed'],
#  ['all', ' convienience', ' dog-user-breed', ' information'],
#  ['all', ' dog-user-breed', ' offers_n_discounts'],
#  ['dog-user-breed'],
#  ['convienience', ' dog-user-breed', ' nutrition_ingredientst'],
#  ['dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['all', ' dog-user-breed'],
#  ['dog-user-breed'],
#  ['dog-user-breed', ' pricing']]

# %%
out =[]
f = open('Pedigree_autoresponses/fine_grained_phrases_pedigree_sentiment_sub_clusters/aspects/dog-user-breed.txt','r+')
breed_names = [i.replace('\n','') for i in list(f.readlines())]
np_array = np.array(breed_names)
for row in dog_breed.to_dict('records'):
  #  a = list(row['aspect'])
    #a = [x.strip(' ') for x in a]
    #index = a.index('dog-user-breed')
    key = list(row['aspect_keyword'])
    key = [x.strip(' ') for x in key]
    item_index =np.in1d(key,np_array).nonzero()[0]
    print item_index
    for i in range(0,len(item_index)):
        row['dog_breed_name'] = key[item_index[i]]
        out.append(row)

# %%
out =pd.DataFrame(out)
out
# Out:
#                                                 aspect  \
# 0                                     [dog-user-breed]
# 1                                     [dog-user-breed]
# 2             [dog-user-breed,  information,  pricing]
# 3                               [all,  dog-user-breed]
# 4                                     [dog-user-breed]
# 5                                     [dog-user-breed]
# 6                                     [dog-user-breed]
# 7                               [all,  dog-user-breed]
# 8                               [all,  dog-user-breed]
# 9                               [all,  dog-user-breed]
# 10                                    [dog-user-breed]
# 11                                    [dog-user-breed]
# 12   [dog-user-breed,  nutrition_ingredientst,  siz...
# 13       [all,  condition_of_product,  dog-user-breed]
# 14                    [all,  dog-user-breed,  pricing]
# 15                                    [dog-user-breed]
# 16                                    [dog-user-breed]
# 17               [all,  convienience,  dog-user-breed]
# 18   [dog-user-breed,  nutrition_ingredientst,  pri...
# 19                                    [dog-user-breed]
# 20   [all,  dog-user-breed,  offers_n_discounts,  p...
# 21                                    [dog-user-breed]
# 22                                    [dog-user-breed]
# 23                          [dog-user-breed,  pricing]
# 24                                    [dog-user-breed]
# 25   [all,  delivery,  dog-user-breed,  information...
# 26                              [all,  dog-user-breed]
# 27                                    [dog-user-breed]
# 28   [all,  condition_of_product,  convienience,  d...
# 29   [all,  condition_of_product,  convienience,  d...
# ..                                                 ...
# 311                                   [dog-user-breed]
# 312                                   [dog-user-breed]
# 313                                   [dog-user-breed]
# 314                                   [dog-user-breed]
# 315                                   [dog-user-breed]
# 316                                   [dog-user-breed]
# 317                                   [dog-user-breed]
# 318                                   [dog-user-breed]
# 319                                   [dog-user-breed]
# 320                                   [dog-user-breed]
# 321                                   [dog-user-breed]
# 322                                   [dog-user-breed]
# 323  [condition_of_product,  dog-user-breed,  offer...
# 324  [all,  condition_of_product,  dog-user-breed, ...
# 325                    [convienience,  dog-user-breed]
# 326                                   [dog-user-breed]
# 327                                   [dog-user-breed]
# 328                             [all,  dog-user-breed]
# 329            [condition_of_product,  dog-user-breed]
# 330                                   [dog-user-breed]
# 331  [all,  delivery,  dog-user-breed,  offers_n_di...
# 332                                   [dog-user-breed]
# 333                  [all,  delivery,  dog-user-breed]
# 334                             [all,  dog-user-breed]
# 335      [all,  condition_of_product,  dog-user-breed]
# 336                             [all,  dog-user-breed]
# 337                                   [dog-user-breed]
# 338                                   [dog-user-breed]
# 339                                   [dog-user-breed]
# 340                             [all,  dog-user-breed]
#
#                                         aspect_keyword  confidence_score  \
# 0                         [shepherd,  german shepherd]         19.558333
# 1                         [shepherd,  german shepherd]         19.558333
# 2            [labrador,  medium,  size,  size,  price]         49.963333
# 3                                      [product,  pug]         88.303333
# 4                                            [shepard]         28.730000
# 5                                          [dachshund]         -9.213333
# 6                                                [gsd]         95.450000
# 7                                     [stix,  bernard]         43.095000
# 8               [product,  shepherd,  german shepherd]        -95.690000
# 9               [product,  shepherd,  german shepherd]        -95.690000
# 10                                               [gsd]        -31.623333
# 11                                        [rottweiler]         96.150000
# 12          [gsd,  meaty,  chocolate,  cubes,  smells]         98.200000
# 13                               [product,  dry,  gsd]        -88.490000
# 14      [pedigree,  product,  male,  labrador,  price]         20.087500
# 15                                       [pug,  puppy]         97.120000
# 16                                          [labrador]         41.605000
# 17               [product,  pedigree,  packing,  dane]         61.220000
# 18           [bull,  medium,  rice,  chicken,  priced]         21.960909
# 19                                               [gsd]         94.870000
# 20                       [market,  gsd,  deal,  price]         88.885000
# 21                                               [gsd]         45.855000
# 22                                             [boxer]        -83.210000
# 23                                [rottweiler,  price]         97.870000
# 24                                         [shepherds]         88.490000
# 25   [product,  delivery,  labrador,  breeds,  pupp...         17.337500
# 26                                    [pedigree,  gsd]         90.290000
# 27                                               [gsd]         95.800000
# 28   [pedigree,  dry,  pack,  puppy,  shepherd,  ge...         49.820000
# 29   [pedigree,  dry,  pack,  puppy,  shepherd,  ge...         49.820000
# ..                                                 ...               ...
# 311                                              [pug]          0.000000
# 312                                            [bosco]         43.710000
# 313                                          [bulldog]          0.000000
# 314                                           [beagle]          0.000000
# 315                                 [labrador,  puppy]          0.000000
# 316                                             [bull]        -46.665000
# 317                       [shepherd,  german shepherd]         49.160000
# 318                       [shepherd,  german shepherd]         49.160000
# 319                                              [pug]        -83.210000
# 320                                         [labrador]         90.290000
# 321                                      [gsd,  puppy]         48.710000
# 322                                              [pug]          0.000000
# 323                             [dry,  beagle,  offer]         47.435000
# 324  [pedigree,  paste,  gsd,  pup,  chicken,  chunks]         44.135000
# 325                          [packet,  packing,  part]        -58.953333
# 326                                              [gsd]         -3.073333
# 327                                              [pug]         86.190000
# 328                               [product,  labrador]        -95.940000
# 329                               [dry,  pug,  breeds]         16.725000
# 330                                              [gsd]         47.755000
# 331             [product,  delivery,  part,  discount]         93.476667
# 332                                              [pug]         83.210000
# 333                         [product,  delivery,  gsd]         89.960000
# 334                               [product,  labrador]         98.130000
# 335                    [pedigree,  hard,  pug,  puppy]        -63.940000
# 336                          [product,  seller,  part]        -91.810000
# 337                                         [labrador]         98.130000
# 338               [shepherd,  puppy,  german shepherd]         28.730000
# 339               [shepherd,  puppy,  german shepherd]         28.730000
# 340                             [product,  rottweiler]         87.340000
#
#       dog_breed_name  flag      id  polarity  \
# 0    german shepherd     0  112570  positive
# 1    german shepherd     0  112570  positive
# 2           labrador     0  110686  positive
# 3                pug     0  110346  positive
# 4            shepard     0  109674  positive
# 5          dachshund     0  108576  negative
# 6                gsd     0  107865  positive
# 7            bernard     0  110702  positive
# 8    german shepherd     0  106810  negative
# 9    german shepherd     0  106810  negative
# 10               gsd     0  112776  negative
# 11        rottweiler     0  113286  positive
# 12               gsd     0  108664  positive
# 13               gsd     0  110358  negative
# 14          labrador     0  108780  positive
# 15               pug     0  106818  positive
# 16          labrador     0  108837  positive
# 17              dane     0  109620  positive
# 18              bull     0  108553  positive
# 19               gsd     0  110413  positive
# 20               gsd     0  110648  positive
# 21               gsd     0  108984  positive
# 22             boxer     0  108019  negative
# 23        rottweiler     0  110147  positive
# 24         shepherds     0  107864  positive
# 25          labrador     0  110096  positive
# 26               gsd     0  108907  positive
# 27               gsd     0  113180  positive
# 28   german shepherd     0  110193  positive
# 29   german shepherd     0  110193  positive
# ..               ...   ...     ...       ...
# 311              pug     0  103769  negative
# 312            bosco     0  103771  positive
# 313          bulldog     0  103833  negative
# 314           beagle     0  103746  negative
# 315         labrador     1  103050   neutral
# 316             bull     0  103419  negative
# 317  german shepherd     0  102985  positive
# 318  german shepherd     0  102985  positive
# 319              pug     0  102910  negative
# 320         labrador     0  114182  positive
# 321              gsd     0  111569  positive
# 322              pug     0  112291  negative
# 323           beagle     0  112134  positive
# 324              gsd     0  111464  positive
# 325             part     0  111939  negative
# 326              gsd     0  112302  negative
# 327              pug     0  112275  positive
# 328         labrador     0  111788  negative
# 329              pug     0  111573  positive
# 330              gsd     0  111899  positive
# 331             part     0  111814  positive
# 332              pug     0  112240  positive
# 333              gsd     0  111600  positive
# 334         labrador     0  111621  positive
# 335              pug     0  111524  negative
# 336             part     0  112198  negative
# 337         labrador     0  112041  positive
# 338  german shepherd     1  111542   neutral
# 339  german shepherd     1  111542   neutral
# 340       rottweiler     0  111609  positive
#
#                                               response  \
# 0    We are happy that the product met your expecta...
# 1    We are happy that the product met your expecta...
# 2    We are happy that the product met your expecta...
# 3    Glad that your pet liked it customer name. Tha...
# 4    Our customers are our first priority. We are h...
# 5    Dear Robin Richard, We apologize for the incon...
# 6    We are happy that the product met your expecta...
# 7    Glad that your pet liked it customer name. Tha...
# 8    Dear laanu, We apologize for the inconvenience...
# 9    Dear laanu, We apologize for the inconvenience...
# 10   Dear Don, We apologize for the inconvenience c...
# 11   Our customers are our first priority. We are h...
# 12   Glad that your pet liked it customer name. Tha...
# 13   Dear Amazon Customer, We apologize for the inc...
# 14   Our customers are our first priority. We are h...
# 15   We are happy that the product met your expecta...
# 16   Glad that your pet liked it customer name. Tha...
# 17   Glad that your pet liked it customer name. Tha...
# 18   Glad that your pet liked it customer name. Tha...
# 19   Our customers are our first priority. We are h...
# 20   Glad that your pet liked it customer name. Tha...
# 21   Glad that your pet liked it customer name. Tha...
# 22   Dear Amazon Customer, We apologize for the inc...
# 23   Our customers are our first priority. We are h...
# 24   Our customers are our first priority. We are h...
# 25   Our customers are our first priority. We are h...
# 26   Glad that your pet liked it customer name. Tha...
# 27   Our customers are our first priority. We are h...
# 28   Glad that your pet liked it customer name. Tha...
# 29   Glad that your pet liked it customer name. Tha...
# ..                                                 ...
# 311  Glad that your pet liked it customer name. Tha...
# 312  Glad that your pet liked it customer name. Tha...
# 313  Our customers are our first priority. We are h...
# 314  Glad that your pet liked it customer name. Tha...
# 315  Dear Rii Das, for any queries and facts regard...
# 316  Dear Anoop K Nair, We are sorry for the inconv...
# 317  We are happy that the product met your expecta...
# 318  We are happy that the product met your expecta...
# 319  Dear Sanjay Day, We apologize for the bother c...
# 320  We are happy that the product met your expecta...
# 321  Glad that your pet liked it customer name. Tha...
# 322  Our customers are our first priority. We are h...
# 323  Glad that your pet liked it customer name. Tha...
# 324  We are happy that the product met your expecta...
# 325  Dear Naeem Inamdar, We apologize for the bothe...
# 326  Dear VIJAY  KAYARKAR, We apologize for the inc...
# 327  Glad that your pet liked it customer name. Tha...
# 328  Dear Vinit Shukla, We apologize for the bother...
# 329  Our customers are our first priority. We are h...
# 330  Glad that your pet liked it customer name. Tha...
# 331  Our customers are our first priority. We are h...
# 332  Glad that your pet liked it customer name. Tha...
# 333  We are happy that the product met your expecta...
# 334  Our customers are our first priority. We are h...
# 335  Dear Flipkart Customer, We are sorry for the d...
# 336  Dear Flipkart Customer, We are sorry for the d...
# 337  Our customers are our first priority. We are h...
# 338  Dear Vibhav  Pal, for any queries and facts re...
# 339  Dear Vibhav  Pal, for any queries and facts re...
# 340  Our customers are our first priority. We are h...
#
#      response_confidence_score  \
# 0                        98.00
# 1                        98.00
# 2                       100.00
# 3                        99.35
# 4                       100.00
# 5                        98.00
# 6                       100.00
# 7                        99.35
# 8                        99.35
# 9                        99.35
# 10                       98.00
# 11                      100.00
# 12                      100.00
# 13                       99.35
# 14                       98.70
# 15                      100.00
# 16                      100.00
# 17                       98.05
# 18                      100.00
# 19                      100.00
# 20                      100.00
# 21                      100.00
# 22                      100.00
# 23                      100.00
# 24                      100.00
# 25                       98.70
# 26                       99.35
# 27                       98.00
# 28                       98.70
# 29                       98.70
# ..                         ...
# 311                     100.00
# 312                     100.00
# 313                     100.00
# 314                     100.00
# 315                     100.00
# 316                     100.00
# 317                     100.00
# 318                     100.00
# 319                      98.00
# 320                     100.00
# 321                     100.00
# 322                     100.00
# 323                     100.00
# 324                      99.35
# 325                      98.70
# 326                     100.00
# 327                     100.00
# 328                      99.35
# 329                     100.00
# 330                      98.00
# 331                      98.70
# 332                     100.00
# 333                      98.70
# 334                      99.35
# 335                      99.35
# 336                      98.70
# 337                     100.00
# 338                     100.00
# 339                     100.00
# 340                      99.35
#
#                                            review_text  \
# 0    The same thing happened to my German Shepherd ...
# 1    The same thing happened to my German Shepherd ...
# 2    The sticks work fine when given on alternate d...
# 3    Another Good product for pedigree.My pug loves...
# 4                 My 8year old German Shepard loves it
# 5    Food seems to be okay. But my dog (a 2.5 year ...
# 6                                 Good liked by my gsd
# 7    MY Saint Bernard loves them.. This is the only...
# 8    very bad product my german shepherd does not l...
# 9    very bad product my german shepherd does not l...
# 10   My labra didn't love it. He is such a foody bu...
# 11                             My Rottweiler loved it.
# 12   Nice little brown cubes, smells like meaty cho...
# 13   It is some product for my GSD  my GSD not eat ...
# 14   I used to get Drools 20kg for around 22-2400 f...
# 15   My pug loves this better than Royal Canine Min...
# 16             HE DIDNT LIKE IT. ITS A LABRADOR ADULT.
# 17   Giving it to my 2 month old great dane and see...
# 18   My pit bull picks at this. This food is medium...
# 19                              My gsd just love it...
# 20   My pet loves it (GSD - adult)! It is a tad exp...
# 21                                       My gsd enjoys
# 22                 My boxer female dog didn't like it.
# 23   Best for your dog at competitive price. I give...
# 24                   Is this good for German Shepherds
# 25   Product is nice especially for Labrador and ot...
# 26           I have always trusted Pedigree for my GSD
# 27   Kya ye 5 months old Grman shephard ke liye bes...
# 28   Pedigree combo comes with the regular puppy fo...
# 29   Pedigree combo comes with the regular puppy fo...
# ..                                                 ...
# 311                  Ya & my pug just love dis .. 🙆🙆
# 312                                         Nice Bosco
# 313            Apna bulldog ka lia la la     Rahul Raj
# 314                         Rohit Arora ye wala beagle
# 315        Can I give it to my Labrador puppy daily ??
# 316                                          Bull shit
# 317  Diwali became more graceful if you a great pet...
# 318  Diwali became more graceful if you a great pet...
# 319  Bad food Mera pug dog he wo ye food khake bema...
# 320  my one year old labrador loved it more than ro...
# 321  I am giving this to my 2 month old gsd  , and ...
# 322                   Our Pug, Buddy love's them......
# 323  My beagle n pomeranian just love it when i mix...
# 324  My GSD pup likes it mixed with pedigree chicke...
# 325  Received a torn packet &amp; was packed in suc...
# 326  God knows.....My Rambo (GSD) didn't like it......
# 327                         My pug loves these treats!
# 328  My Labrador 2 year old is just neglect this pr...
# 329  I give 3 stars because, when soaked in warm wa...
# 330  Refrigerate and serve your dog.  My gsd love i...
# 331  Product is as always awesome. But best part is...
# 332                    My dog(pug) likes it very much.
# 333  My gsd like it very much.... Good product with...
# 334                 Good And Best product for Labrador
# 335  My pug never touch also this pedigree they hav...
# 336  Wrong product supplied and no option for retur...
# 337  This is best food for my Loving Family Member ...
# 338  I just want to know that, can I give this to m...
# 339  I just want to know that, can I give this to m...
# 340             My rottweiler loves it... Good product
#
#                                     reviewer_id          reviewer_name  \
# 0    amzn1.account.AH254SXTBTT7KU6CCLKKXOHVFFVA        Amazon Customer
# 1    amzn1.account.AH254SXTBTT7KU6CCLKKXOHVFFVA        Amazon Customer
# 2    amzn1.account.AENFN6YWXZAA77VSHSDB5GWRMQYA           Anonymous101
# 3    amzn1.account.AED3T2PXSXGSDDZGSXBLACMLHBGA           Sujeet Singh
# 4    amzn1.account.AHUQ22ZJQWM2TOU6F2743BTJBQRQ               Kavin V.
# 5    amzn1.account.AEKE6SJUX5BA3C75DYXIUIEOIL4A          Robin Richard
# 6    amzn1.account.AFCUKOGJQKNTNLEIOLQLSLU5NTUA        Amazon Customer
# 7    amzn1.account.AEEVSISEPH7FVCIRYJPN53MD4JMA                  jomin
# 8    amzn1.account.AESCJVQ5BONATCURAQ2H4MCKCLAA                  laanu
# 9    amzn1.account.AESCJVQ5BONATCURAQ2H4MCKCLAA                  laanu
# 10   amzn1.account.AGOCZ5PEUW2I3OZRQT6MMAZE5UGA                    Don
# 11   amzn1.account.AFWYKTMNYAGHKAJFBDVHW6BFCNPA           Vikram singh
# 12   amzn1.account.AGLJABCR2JVARTJ6NJDPXXOPFRZQ            Purple Hawk
# 13   amzn1.account.AH5FFQLMSWZFOGILN5VRKR2NW5BQ        Amazon Customer
# 14   amzn1.account.AENOCDSGJUH5DPQBGI7ZARTVCIFQ             r0y 0l1v3r
# 15   amzn1.account.AFCJ3KIQ5EHU3IFSOIWRVXN5MXOQ              Amruta YG
# 16   amzn1.account.AHXDOV35SG7Z5SGD6MLGTEQ3OD2Q           Anish Jaitly
# 17   amzn1.account.AFR2IERO6IDZCWDOWAKQT3ZOYQIQ             Nitin Jain
# 18   amzn1.account.AGCHAZIHTQAU65VPTMYOIRDUXQHQ                 Rakesh
# 19   amzn1.account.AFXBWVYLAL6CQLNR5BM4KBHYCI4A        Amazon Customer
# 20   amzn1.account.AFNWGD5AV2WPB6SCYJA7J4JT32BA               TechBuff
# 21   amzn1.account.AGX5GCX44DQAUHGKDIOL7HF53KOQ  PrudhviRaj Siripurapu
# 22   amzn1.account.AGIL5E57SV34EAVT2733KT2DHA2A        Amazon Customer
# 23   amzn1.account.AEFPQZECOO7R4K6FOGXXF7367QQA                  Sunny
# 24   amzn1.account.AHOXL2QQENCUG7NCDIZXLCC6JD7Q        pranshu menaria
# 25   amzn1.account.AGNTK4GDK7BN7N4JVONEZKG3EMUQ        Avaneesh Mishra
# 26   amzn1.account.AEMVFZ4RNHE5XYIVKAYNOWV7WNQA                  Shyam
# 27   amzn1.account.AGQFOORYKG5MJXQIBZJYAAZDKXTA         Amarjit sharma
# 28   amzn1.account.AFY6EBKOQKSUPNH22JSWOSZ2N4GA                 kannan
# 29   amzn1.account.AFY6EBKOQKSUPNH22JSWOSZ2N4GA                 kannan
# ..                                          ...                    ...
# 311                            1426644787446634           Indu Chandel
# 312                            1970626979855697         Surendra Singh
# 313                            2009554492704050                 Vishnu
# 314                             572400826431622          Shikha Mittal
# 315                             411660572620229                Rii Das
# 316                            1707542952708762           Anoop K Nair
# 317                            1811703755527467      Aditya Singh Gaur
# 318                            1811703755527467      Aditya Singh Gaur
# 319                            1619264381443688             Sanjay Day
# 320                                         NaN     prashant  debbarma
# 321                                         NaN               Ajay Das
# 322                                         NaN      Flipkart Customer
# 323                                         NaN    Dr Rital Bambhaniya
# 324                                         NaN           Orrible Kunt
# 325                                         NaN          Naeem Inamdar
# 326                                         NaN        VIJAY  KAYARKAR
# 327                                         NaN            Shreya Sood
# 328                                         NaN           Vinit Shukla
# 329                                         NaN        S%20S SARAVANAN
# 330                                         NaN      Vinay kumar  Guli
# 331                                         NaN            Puneet Tuli
# 332                                         NaN            Tapan Nandi
# 333                                         NaN          N kumar Verma
# 334                                         NaN      Flipkart Customer
# 335                                         NaN      Flipkart Customer
# 336                                         NaN      Flipkart Customer
# 337                                         NaN       Archana  Ramawat
# 338                                         NaN            Vibhav  Pal
# 339                                         NaN            Vibhav  Pal
# 340                                         NaN      Flipkart Customer
#
#       source_name                      source_review_id         star_rating
# 0    Amazon India                       Mx161SNL9KB1S36                   0
# 1    Amazon India                       Mx161SNL9KB1S36                   0
# 2    Amazon India                        R11JH67UHVL536  3.0 out of 5 stars
# 3    Amazon India                        R12P5KP5L5LVWQ  5.0 out of 5 stars
# 4    Amazon India                        R13951GCV9PFAM  5.0 out of 5 stars
# 5    Amazon India                        R13C16SKTYC7NZ  3.0 out of 5 stars
# 6    Amazon India                        R13FJMD61HF18Z                 4.0
# 7    Amazon India                        R14CW680YCRB3U  5.0 out of 5 stars
# 8    Amazon India                        R14M3K21HNG0FD  1.0 out of 5 stars
# 9    Amazon India                        R14M3K21HNG0FD  1.0 out of 5 stars
# 10   Amazon India                        R14NAUVYK66XW3                 1.0
# 11   Amazon India                        R14Q2WTA4R120B                 4.0
# 12   Amazon India                         R15DMYGWGK3T1  5.0 out of 5 stars
# 13   Amazon India                        R16F5IB7GDYPP6  5.0 out of 5 stars
# 14   Amazon India                        R16PUUHLNRZFA0  5.0 out of 5 stars
# 15   Amazon India                        R16QMB28O51S3J  5.0 out of 5 stars
# 16   Amazon India                        R17J0H9MM6IVCT  2.0 out of 5 stars
# 17   Amazon India                        R17USJHW4IGDR8  5.0 out of 5 stars
# 18   Amazon India                        R18EO32R9NXM6Q  3.0 out of 5 stars
# 19   Amazon India                        R1965D6DMQXNDR  5.0 out of 5 stars
# 20   Amazon India                        R19RZ3UB98FHHE  4.0 out of 5 stars
# 21   Amazon India                        R1A1XFUBJIYUL7  5.0 out of 5 stars
# 22   Amazon India                        R1AW08GRREZCY0                 1.0
# 23   Amazon India                        R1B2LB2SZOCF1G  5.0 out of 5 stars
# 24   Amazon India                        R1BH5QI3XP4T4X                 4.0
# 25   Amazon India                        R1C4I6BUH6M7Q5  4.0 out of 5 stars
# 26   Amazon India                        R1CTSRAN31V0ND  5.0 out of 5 stars
# 27   Amazon India                        R1DZ53NHCAAYG8                 4.0
# 28   Amazon India                        R1E06ORMNLQFFX                 5.0
# 29   Amazon India                        R1E06ORMNLQFFX                 5.0
# ..            ...                                   ...                 ...
# 311      Facebook     1851909968402343_1851936381733035                 NaN
# 312      Facebook     1851909968402343_1851938621732811                 NaN
# 313      Facebook     1851909968402343_1855214251405248                 NaN
# 314      Facebook     1916732655253407_1921031574823515                 NaN
# 315      Facebook     1928414317418574_1937677189825620                 NaN
# 316      Facebook     1928414317418574_1954468144813191                 NaN
# 317      Facebook     1937502959843043_1938325049760834                 NaN
# 318      Facebook     1937502959843043_1938325049760834                 NaN
# 319      Facebook     1980766808849991_1981006688826003                 NaN
# 320      Flipkart  3a733051-e63f-41ad-9f00-db4c5d9318f9                   5
# 321      Flipkart  3ba3133d-7946-432f-aaed-0aefd822cc3d                   2
# 322      Flipkart  3dd8109e-92ea-4b41-9665-cd72a2021108                   4
# 323      Flipkart  5231fb8a-8a8f-41e0-a028-01148c1db099                   5
# 324      Flipkart  52897612-f925-4f91-bda3-20a95f97a929                   5
# 325      Flipkart  5b97b5bc-a24a-4382-9b39-b49bc803fae7                   1
# 326      Flipkart  5da81e70-c34a-4144-a096-21463eec25f8                   1
# 327      Flipkart  616bcb01-6427-4770-aeaf-daf680849c17                   5
# 328      Flipkart  68e4a953-52c8-4fdd-b923-ed38be0eb8a2                   1
# 329      Flipkart  7a3ebf79-496c-4d43-8407-acc6bd1c3a34                   3
# 330      Flipkart  7b115f33-e4a7-4fe1-8b28-41bb5a3fb5a0                   5
# 331      Flipkart  7df3ca2a-b853-4a19-8e28-dbf5682015a7                   5
# 332      Flipkart  7e1d6d49-aa13-411a-acd4-375bd84096de                   5
# 333      Flipkart  956949f8-db07-4852-9481-d496fb77d1a7                   4
# 334      Flipkart  99174fff-c5d8-465e-9afe-4956e65463b5                   4
# 335      Flipkart  9ef8886e-d574-42bd-952f-ef5107c453b5                   1
# 336      Flipkart  ac80301b-0852-46a9-8e2b-d099c44e74a9                   1
# 337      Flipkart  c62d739e-bd81-405e-bca1-61151d2daf94                   5
# 338      Flipkart  cf2eb94a-8840-4cc8-a7f8-1fe86c0a4470                   1
# 339      Flipkart  cf2eb94a-8840-4cc8-a7f8-1fe86c0a4470                   1
# 340      Flipkart  f0906b0b-4429-45f2-b67e-5b9e9f79df90                   5
#
# [341 rows x 15 columns]

# %%
out_filter = out[out.dog_breed_name.isin(breed_names)]

# %%
out_filter_1=[]
for row in out_filter.to_dict("records"):
    row['dog_breed_name'] = row['dog_breed_name'].replace('gsd',"german shepherd").replace('cocker',"cocker spaniel").replace('cocker spaniel spaniel',"cocker spaniel").replace('shepard',"german shepherd").replace('shepherd',"german shepherd").replace('german german shepherd',"german shepherd").replace('german shepherds',"german shepherd").replace('shepherd',"german shepherd").replace('german german shepherd',"german shepherd").replace('retriver',"retriever").replace('bull',"bull dog").replace('labs',"labrador").replace('bull dogdog',"bull dog").lower()
    out_filter_1.append(row)
out_filter_1 = pd.DataFrame(out_filter_1)

# %%
out_filter_1.to_csv('Breed_Wise_and_review_wise_polarity_insights.csv',sep=',',quoting=csv.QUOTE_ALL,encoding='utf-8',index=False,columns =['id','source_review_id','dog_breed_name','polarity','confidence_score'])

# %%
out_filter_1
# Out:
#                                                 aspect  \
# 0                                     [dog-user-breed]
# 1                                     [dog-user-breed]
# 2             [dog-user-breed,  information,  pricing]
# 3                               [all,  dog-user-breed]
# 4                                     [dog-user-breed]
# 5                                     [dog-user-breed]
# 6                                     [dog-user-breed]
# 7                               [all,  dog-user-breed]
# 8                               [all,  dog-user-breed]
# 9                               [all,  dog-user-breed]
# 10                                    [dog-user-breed]
# 11                                    [dog-user-breed]
# 12   [dog-user-breed,  nutrition_ingredientst,  siz...
# 13       [all,  condition_of_product,  dog-user-breed]
# 14                    [all,  dog-user-breed,  pricing]
# 15                                    [dog-user-breed]
# 16                                    [dog-user-breed]
# 17               [all,  convienience,  dog-user-breed]
# 18   [dog-user-breed,  nutrition_ingredientst,  pri...
# 19                                    [dog-user-breed]
# 20   [all,  dog-user-breed,  offers_n_discounts,  p...
# 21                                    [dog-user-breed]
# 22                                    [dog-user-breed]
# 23                          [dog-user-breed,  pricing]
# 24                                    [dog-user-breed]
# 25   [all,  delivery,  dog-user-breed,  information...
# 26                              [all,  dog-user-breed]
# 27                                    [dog-user-breed]
# 28   [all,  condition_of_product,  convienience,  d...
# 29   [all,  condition_of_product,  convienience,  d...
# ..                                                 ...
# 311                                   [dog-user-breed]
# 312                                   [dog-user-breed]
# 313                                   [dog-user-breed]
# 314                                   [dog-user-breed]
# 315                                   [dog-user-breed]
# 316                                   [dog-user-breed]
# 317                                   [dog-user-breed]
# 318                                   [dog-user-breed]
# 319                                   [dog-user-breed]
# 320                                   [dog-user-breed]
# 321                                   [dog-user-breed]
# 322                                   [dog-user-breed]
# 323  [condition_of_product,  dog-user-breed,  offer...
# 324  [all,  condition_of_product,  dog-user-breed, ...
# 325                    [convienience,  dog-user-breed]
# 326                                   [dog-user-breed]
# 327                                   [dog-user-breed]
# 328                             [all,  dog-user-breed]
# 329            [condition_of_product,  dog-user-breed]
# 330                                   [dog-user-breed]
# 331  [all,  delivery,  dog-user-breed,  offers_n_di...
# 332                                   [dog-user-breed]
# 333                  [all,  delivery,  dog-user-breed]
# 334                             [all,  dog-user-breed]
# 335      [all,  condition_of_product,  dog-user-breed]
# 336                             [all,  dog-user-breed]
# 337                                   [dog-user-breed]
# 338                                   [dog-user-breed]
# 339                                   [dog-user-breed]
# 340                             [all,  dog-user-breed]
#
#                                         aspect_keyword  confidence_score  \
# 0                         [shepherd,  german shepherd]         19.558333
# 1                         [shepherd,  german shepherd]         19.558333
# 2            [labrador,  medium,  size,  size,  price]         49.963333
# 3                                      [product,  pug]         88.303333
# 4                                            [shepard]         28.730000
# 5                                          [dachshund]         -9.213333
# 6                                                [gsd]         95.450000
# 7                                     [stix,  bernard]         43.095000
# 8               [product,  shepherd,  german shepherd]        -95.690000
# 9               [product,  shepherd,  german shepherd]        -95.690000
# 10                                               [gsd]        -31.623333
# 11                                        [rottweiler]         96.150000
# 12          [gsd,  meaty,  chocolate,  cubes,  smells]         98.200000
# 13                               [product,  dry,  gsd]        -88.490000
# 14      [pedigree,  product,  male,  labrador,  price]         20.087500
# 15                                       [pug,  puppy]         97.120000
# 16                                          [labrador]         41.605000
# 17               [product,  pedigree,  packing,  dane]         61.220000
# 18           [bull,  medium,  rice,  chicken,  priced]         21.960909
# 19                                               [gsd]         94.870000
# 20                       [market,  gsd,  deal,  price]         88.885000
# 21                                               [gsd]         45.855000
# 22                                             [boxer]        -83.210000
# 23                                [rottweiler,  price]         97.870000
# 24                                         [shepherds]         88.490000
# 25   [product,  delivery,  labrador,  breeds,  pupp...         17.337500
# 26                                    [pedigree,  gsd]         90.290000
# 27                                               [gsd]         95.800000
# 28   [pedigree,  dry,  pack,  puppy,  shepherd,  ge...         49.820000
# 29   [pedigree,  dry,  pack,  puppy,  shepherd,  ge...         49.820000
# ..                                                 ...               ...
# 311                                              [pug]          0.000000
# 312                                            [bosco]         43.710000
# 313                                          [bulldog]          0.000000
# 314                                           [beagle]          0.000000
# 315                                 [labrador,  puppy]          0.000000
# 316                                             [bull]        -46.665000
# 317                       [shepherd,  german shepherd]         49.160000
# 318                       [shepherd,  german shepherd]         49.160000
# 319                                              [pug]        -83.210000
# 320                                         [labrador]         90.290000
# 321                                      [gsd,  puppy]         48.710000
# 322                                              [pug]          0.000000
# 323                             [dry,  beagle,  offer]         47.435000
# 324  [pedigree,  paste,  gsd,  pup,  chicken,  chunks]         44.135000
# 325                          [packet,  packing,  part]        -58.953333
# 326                                              [gsd]         -3.073333
# 327                                              [pug]         86.190000
# 328                               [product,  labrador]        -95.940000
# 329                               [dry,  pug,  breeds]         16.725000
# 330                                              [gsd]         47.755000
# 331             [product,  delivery,  part,  discount]         93.476667
# 332                                              [pug]         83.210000
# 333                         [product,  delivery,  gsd]         89.960000
# 334                               [product,  labrador]         98.130000
# 335                    [pedigree,  hard,  pug,  puppy]        -63.940000
# 336                          [product,  seller,  part]        -91.810000
# 337                                         [labrador]         98.130000
# 338               [shepherd,  puppy,  german shepherd]         28.730000
# 339               [shepherd,  puppy,  german shepherd]         28.730000
# 340                             [product,  rottweiler]         87.340000
#
#       dog_breed_name  flag      id  polarity  \
# 0    german shepherd     0  112570  positive
# 1    german shepherd     0  112570  positive
# 2           labrador     0  110686  positive
# 3                pug     0  110346  positive
# 4    german shepherd     0  109674  positive
# 5          dachshund     0  108576  negative
# 6    german shepherd     0  107865  positive
# 7            bernard     0  110702  positive
# 8    german shepherd     0  106810  negative
# 9    german shepherd     0  106810  negative
# 10   german shepherd     0  112776  negative
# 11        rottweiler     0  113286  positive
# 12   german shepherd     0  108664  positive
# 13   german shepherd     0  110358  negative
# 14          labrador     0  108780  positive
# 15               pug     0  106818  positive
# 16          labrador     0  108837  positive
# 17              dane     0  109620  positive
# 18          bull dog     0  108553  positive
# 19   german shepherd     0  110413  positive
# 20   german shepherd     0  110648  positive
# 21   german shepherd     0  108984  positive
# 22             boxer     0  108019  negative
# 23        rottweiler     0  110147  positive
# 24   german shepherd     0  107864  positive
# 25          labrador     0  110096  positive
# 26   german shepherd     0  108907  positive
# 27   german shepherd     0  113180  positive
# 28   german shepherd     0  110193  positive
# 29   german shepherd     0  110193  positive
# ..               ...   ...     ...       ...
# 311              pug     0  103769  negative
# 312            bosco     0  103771  positive
# 313         bull dog     0  103833  negative
# 314           beagle     0  103746  negative
# 315         labrador     1  103050   neutral
# 316         bull dog     0  103419  negative
# 317  german shepherd     0  102985  positive
# 318  german shepherd     0  102985  positive
# 319              pug     0  102910  negative
# 320         labrador     0  114182  positive
# 321  german shepherd     0  111569  positive
# 322              pug     0  112291  negative
# 323           beagle     0  112134  positive
# 324  german shepherd     0  111464  positive
# 325             part     0  111939  negative
# 326  german shepherd     0  112302  negative
# 327              pug     0  112275  positive
# 328         labrador     0  111788  negative
# 329              pug     0  111573  positive
# 330  german shepherd     0  111899  positive
# 331             part     0  111814  positive
# 332              pug     0  112240  positive
# 333  german shepherd     0  111600  positive
# 334         labrador     0  111621  positive
# 335              pug     0  111524  negative
# 336             part     0  112198  negative
# 337         labrador     0  112041  positive
# 338  german shepherd     1  111542   neutral
# 339  german shepherd     1  111542   neutral
# 340       rottweiler     0  111609  positive
#
#                                               response  \
# 0    We are happy that the product met your expecta...
# 1    We are happy that the product met your expecta...
# 2    We are happy that the product met your expecta...
# 3    Glad that your pet liked it customer name. Tha...
# 4    Our customers are our first priority. We are h...
# 5    Dear Robin Richard, We apologize for the incon...
# 6    We are happy that the product met your expecta...
# 7    Glad that your pet liked it customer name. Tha...
# 8    Dear laanu, We apologize for the inconvenience...
# 9    Dear laanu, We apologize for the inconvenience...
# 10   Dear Don, We apologize for the inconvenience c...
# 11   Our customers are our first priority. We are h...
# 12   Glad that your pet liked it customer name. Tha...
# 13   Dear Amazon Customer, We apologize for the inc...
# 14   Our customers are our first priority. We are h...
# 15   We are happy that the product met your expecta...
# 16   Glad that your pet liked it customer name. Tha...
# 17   Glad that your pet liked it customer name. Tha...
# 18   Glad that your pet liked it customer name. Tha...
# 19   Our customers are our first priority. We are h...
# 20   Glad that your pet liked it customer name. Tha...
# 21   Glad that your pet liked it customer name. Tha...
# 22   Dear Amazon Customer, We apologize for the inc...
# 23   Our customers are our first priority. We are h...
# 24   Our customers are our first priority. We are h...
# 25   Our customers are our first priority. We are h...
# 26   Glad that your pet liked it customer name. Tha...
# 27   Our customers are our first priority. We are h...
# 28   Glad that your pet liked it customer name. Tha...
# 29   Glad that your pet liked it customer name. Tha...
# ..                                                 ...
# 311  Glad that your pet liked it customer name. Tha...
# 312  Glad that your pet liked it customer name. Tha...
# 313  Our customers are our first priority. We are h...
# 314  Glad that your pet liked it customer name. Tha...
# 315  Dear Rii Das, for any queries and facts regard...
# 316  Dear Anoop K Nair, We are sorry for the inconv...
# 317  We are happy that the product met your expecta...
# 318  We are happy that the product met your expecta...
# 319  Dear Sanjay Day, We apologize for the bother c...
# 320  We are happy that the product met your expecta...
# 321  Glad that your pet liked it customer name. Tha...
# 322  Our customers are our first priority. We are h...
# 323  Glad that your pet liked it customer name. Tha...
# 324  We are happy that the product met your expecta...
# 325  Dear Naeem Inamdar, We apologize for the bothe...
# 326  Dear VIJAY  KAYARKAR, We apologize for the inc...
# 327  Glad that your pet liked it customer name. Tha...
# 328  Dear Vinit Shukla, We apologize for the bother...
# 329  Our customers are our first priority. We are h...
# 330  Glad that your pet liked it customer name. Tha...
# 331  Our customers are our first priority. We are h...
# 332  Glad that your pet liked it customer name. Tha...
# 333  We are happy that the product met your expecta...
# 334  Our customers are our first priority. We are h...
# 335  Dear Flipkart Customer, We are sorry for the d...
# 336  Dear Flipkart Customer, We are sorry for the d...
# 337  Our customers are our first priority. We are h...
# 338  Dear Vibhav  Pal, for any queries and facts re...
# 339  Dear Vibhav  Pal, for any queries and facts re...
# 340  Our customers are our first priority. We are h...
#
#      response_confidence_score  \
# 0                        98.00
# 1                        98.00
# 2                       100.00
# 3                        99.35
# 4                       100.00
# 5                        98.00
# 6                       100.00
# 7                        99.35
# 8                        99.35
# 9                        99.35
# 10                       98.00
# 11                      100.00
# 12                      100.00
# 13                       99.35
# 14                       98.70
# 15                      100.00
# 16                      100.00
# 17                       98.05
# 18                      100.00
# 19                      100.00
# 20                      100.00
# 21                      100.00
# 22                      100.00
# 23                      100.00
# 24                      100.00
# 25                       98.70
# 26                       99.35
# 27                       98.00
# 28                       98.70
# 29                       98.70
# ..                         ...
# 311                     100.00
# 312                     100.00
# 313                     100.00
# 314                     100.00
# 315                     100.00
# 316                     100.00
# 317                     100.00
# 318                     100.00
# 319                      98.00
# 320                     100.00
# 321                     100.00
# 322                     100.00
# 323                     100.00
# 324                      99.35
# 325                      98.70
# 326                     100.00
# 327                     100.00
# 328                      99.35
# 329                     100.00
# 330                      98.00
# 331                      98.70
# 332                     100.00
# 333                      98.70
# 334                      99.35
# 335                      99.35
# 336                      98.70
# 337                     100.00
# 338                     100.00
# 339                     100.00
# 340                      99.35
#
#                                            review_text  \
# 0    The same thing happened to my German Shepherd ...
# 1    The same thing happened to my German Shepherd ...
# 2    The sticks work fine when given on alternate d...
# 3    Another Good product for pedigree.My pug loves...
# 4                 My 8year old German Shepard loves it
# 5    Food seems to be okay. But my dog (a 2.5 year ...
# 6                                 Good liked by my gsd
# 7    MY Saint Bernard loves them.. This is the only...
# 8    very bad product my german shepherd does not l...
# 9    very bad product my german shepherd does not l...
# 10   My labra didn't love it. He is such a foody bu...
# 11                             My Rottweiler loved it.
# 12   Nice little brown cubes, smells like meaty cho...
# 13   It is some product for my GSD  my GSD not eat ...
# 14   I used to get Drools 20kg for around 22-2400 f...
# 15   My pug loves this better than Royal Canine Min...
# 16             HE DIDNT LIKE IT. ITS A LABRADOR ADULT.
# 17   Giving it to my 2 month old great dane and see...
# 18   My pit bull picks at this. This food is medium...
# 19                              My gsd just love it...
# 20   My pet loves it (GSD - adult)! It is a tad exp...
# 21                                       My gsd enjoys
# 22                 My boxer female dog didn't like it.
# 23   Best for your dog at competitive price. I give...
# 24                   Is this good for German Shepherds
# 25   Product is nice especially for Labrador and ot...
# 26           I have always trusted Pedigree for my GSD
# 27   Kya ye 5 months old Grman shephard ke liye bes...
# 28   Pedigree combo comes with the regular puppy fo...
# 29   Pedigree combo comes with the regular puppy fo...
# ..                                                 ...
# 311                  Ya & my pug just love dis .. 🙆🙆
# 312                                         Nice Bosco
# 313            Apna bulldog ka lia la la     Rahul Raj
# 314                         Rohit Arora ye wala beagle
# 315        Can I give it to my Labrador puppy daily ??
# 316                                          Bull shit
# 317  Diwali became more graceful if you a great pet...
# 318  Diwali became more graceful if you a great pet...
# 319  Bad food Mera pug dog he wo ye food khake bema...
# 320  my one year old labrador loved it more than ro...
# 321  I am giving this to my 2 month old gsd  , and ...
# 322                   Our Pug, Buddy love's them......
# 323  My beagle n pomeranian just love it when i mix...
# 324  My GSD pup likes it mixed with pedigree chicke...
# 325  Received a torn packet &amp; was packed in suc...
# 326  God knows.....My Rambo (GSD) didn't like it......
# 327                         My pug loves these treats!
# 328  My Labrador 2 year old is just neglect this pr...
# 329  I give 3 stars because, when soaked in warm wa...
# 330  Refrigerate and serve your dog.  My gsd love i...
# 331  Product is as always awesome. But best part is...
# 332                    My dog(pug) likes it very much.
# 333  My gsd like it very much.... Good product with...
# 334                 Good And Best product for Labrador
# 335  My pug never touch also this pedigree they hav...
# 336  Wrong product supplied and no option for retur...
# 337  This is best food for my Loving Family Member ...
# 338  I just want to know that, can I give this to m...
# 339  I just want to know that, can I give this to m...
# 340             My rottweiler loves it... Good product
#
#                                     reviewer_id          reviewer_name  \
# 0    amzn1.account.AH254SXTBTT7KU6CCLKKXOHVFFVA        Amazon Customer
# 1    amzn1.account.AH254SXTBTT7KU6CCLKKXOHVFFVA        Amazon Customer
# 2    amzn1.account.AENFN6YWXZAA77VSHSDB5GWRMQYA           Anonymous101
# 3    amzn1.account.AED3T2PXSXGSDDZGSXBLACMLHBGA           Sujeet Singh
# 4    amzn1.account.AHUQ22ZJQWM2TOU6F2743BTJBQRQ               Kavin V.
# 5    amzn1.account.AEKE6SJUX5BA3C75DYXIUIEOIL4A          Robin Richard
# 6    amzn1.account.AFCUKOGJQKNTNLEIOLQLSLU5NTUA        Amazon Customer
# 7    amzn1.account.AEEVSISEPH7FVCIRYJPN53MD4JMA                  jomin
# 8    amzn1.account.AESCJVQ5BONATCURAQ2H4MCKCLAA                  laanu
# 9    amzn1.account.AESCJVQ5BONATCURAQ2H4MCKCLAA                  laanu
# 10   amzn1.account.AGOCZ5PEUW2I3OZRQT6MMAZE5UGA                    Don
# 11   amzn1.account.AFWYKTMNYAGHKAJFBDVHW6BFCNPA           Vikram singh
# 12   amzn1.account.AGLJABCR2JVARTJ6NJDPXXOPFRZQ            Purple Hawk
# 13   amzn1.account.AH5FFQLMSWZFOGILN5VRKR2NW5BQ        Amazon Customer
# 14   amzn1.account.AENOCDSGJUH5DPQBGI7ZARTVCIFQ             r0y 0l1v3r
# 15   amzn1.account.AFCJ3KIQ5EHU3IFSOIWRVXN5MXOQ              Amruta YG
# 16   amzn1.account.AHXDOV35SG7Z5SGD6MLGTEQ3OD2Q           Anish Jaitly
# 17   amzn1.account.AFR2IERO6IDZCWDOWAKQT3ZOYQIQ             Nitin Jain
# 18   amzn1.account.AGCHAZIHTQAU65VPTMYOIRDUXQHQ                 Rakesh
# 19   amzn1.account.AFXBWVYLAL6CQLNR5BM4KBHYCI4A        Amazon Customer
# 20   amzn1.account.AFNWGD5AV2WPB6SCYJA7J4JT32BA               TechBuff
# 21   amzn1.account.AGX5GCX44DQAUHGKDIOL7HF53KOQ  PrudhviRaj Siripurapu
# 22   amzn1.account.AGIL5E57SV34EAVT2733KT2DHA2A        Amazon Customer
# 23   amzn1.account.AEFPQZECOO7R4K6FOGXXF7367QQA                  Sunny
# 24   amzn1.account.AHOXL2QQENCUG7NCDIZXLCC6JD7Q        pranshu menaria
# 25   amzn1.account.AGNTK4GDK7BN7N4JVONEZKG3EMUQ        Avaneesh Mishra
# 26   amzn1.account.AEMVFZ4RNHE5XYIVKAYNOWV7WNQA                  Shyam
# 27   amzn1.account.AGQFOORYKG5MJXQIBZJYAAZDKXTA         Amarjit sharma
# 28   amzn1.account.AFY6EBKOQKSUPNH22JSWOSZ2N4GA                 kannan
# 29   amzn1.account.AFY6EBKOQKSUPNH22JSWOSZ2N4GA                 kannan
# ..                                          ...                    ...
# 311                            1426644787446634           Indu Chandel
# 312                            1970626979855697         Surendra Singh
# 313                            2009554492704050                 Vishnu
# 314                             572400826431622          Shikha Mittal
# 315                             411660572620229                Rii Das
# 316                            1707542952708762           Anoop K Nair
# 317                            1811703755527467      Aditya Singh Gaur
# 318                            1811703755527467      Aditya Singh Gaur
# 319                            1619264381443688             Sanjay Day
# 320                                         NaN     prashant  debbarma
# 321                                         NaN               Ajay Das
# 322                                         NaN      Flipkart Customer
# 323                                         NaN    Dr Rital Bambhaniya
# 324                                         NaN           Orrible Kunt
# 325                                         NaN          Naeem Inamdar
# 326                                         NaN        VIJAY  KAYARKAR
# 327                                         NaN            Shreya Sood
# 328                                         NaN           Vinit Shukla
# 329                                         NaN        S%20S SARAVANAN
# 330                                         NaN      Vinay kumar  Guli
# 331                                         NaN            Puneet Tuli
# 332                                         NaN            Tapan Nandi
# 333                                         NaN          N kumar Verma
# 334                                         NaN      Flipkart Customer
# 335                                         NaN      Flipkart Customer
# 336                                         NaN      Flipkart Customer
# 337                                         NaN       Archana  Ramawat
# 338                                         NaN            Vibhav  Pal
# 339                                         NaN            Vibhav  Pal
# 340                                         NaN      Flipkart Customer
#
#       source_name                      source_review_id         star_rating
# 0    Amazon India                       Mx161SNL9KB1S36                   0
# 1    Amazon India                       Mx161SNL9KB1S36                   0
# 2    Amazon India                        R11JH67UHVL536  3.0 out of 5 stars
# 3    Amazon India                        R12P5KP5L5LVWQ  5.0 out of 5 stars
# 4    Amazon India                        R13951GCV9PFAM  5.0 out of 5 stars
# 5    Amazon India                        R13C16SKTYC7NZ  3.0 out of 5 stars
# 6    Amazon India                        R13FJMD61HF18Z                 4.0
# 7    Amazon India                        R14CW680YCRB3U  5.0 out of 5 stars
# 8    Amazon India                        R14M3K21HNG0FD  1.0 out of 5 stars
# 9    Amazon India                        R14M3K21HNG0FD  1.0 out of 5 stars
# 10   Amazon India                        R14NAUVYK66XW3                 1.0
# 11   Amazon India                        R14Q2WTA4R120B                 4.0
# 12   Amazon India                         R15DMYGWGK3T1  5.0 out of 5 stars
# 13   Amazon India                        R16F5IB7GDYPP6  5.0 out of 5 stars
# 14   Amazon India                        R16PUUHLNRZFA0  5.0 out of 5 stars
# 15   Amazon India                        R16QMB28O51S3J  5.0 out of 5 stars
# 16   Amazon India                        R17J0H9MM6IVCT  2.0 out of 5 stars
# 17   Amazon India                        R17USJHW4IGDR8  5.0 out of 5 stars
# 18   Amazon India                        R18EO32R9NXM6Q  3.0 out of 5 stars
# 19   Amazon India                        R1965D6DMQXNDR  5.0 out of 5 stars
# 20   Amazon India                        R19RZ3UB98FHHE  4.0 out of 5 stars
# 21   Amazon India                        R1A1XFUBJIYUL7  5.0 out of 5 stars
# 22   Amazon India                        R1AW08GRREZCY0                 1.0
# 23   Amazon India                        R1B2LB2SZOCF1G  5.0 out of 5 stars
# 24   Amazon India                        R1BH5QI3XP4T4X                 4.0
# 25   Amazon India                        R1C4I6BUH6M7Q5  4.0 out of 5 stars
# 26   Amazon India                        R1CTSRAN31V0ND  5.0 out of 5 stars
# 27   Amazon India                        R1DZ53NHCAAYG8                 4.0
# 28   Amazon India                        R1E06ORMNLQFFX                 5.0
# 29   Amazon India                        R1E06ORMNLQFFX                 5.0
# ..            ...                                   ...                 ...
# 311      Facebook     1851909968402343_1851936381733035                 NaN
# 312      Facebook     1851909968402343_1851938621732811                 NaN
# 313      Facebook     1851909968402343_1855214251405248                 NaN
# 314      Facebook     1916732655253407_1921031574823515                 NaN
# 315      Facebook     1928414317418574_1937677189825620                 NaN
# 316      Facebook     1928414317418574_1954468144813191                 NaN
# 317      Facebook     1937502959843043_1938325049760834                 NaN
# 318      Facebook     1937502959843043_1938325049760834                 NaN
# 319      Facebook     1980766808849991_1981006688826003                 NaN
# 320      Flipkart  3a733051-e63f-41ad-9f00-db4c5d9318f9                   5
# 321      Flipkart  3ba3133d-7946-432f-aaed-0aefd822cc3d                   2
# 322      Flipkart  3dd8109e-92ea-4b41-9665-cd72a2021108                   4
# 323      Flipkart  5231fb8a-8a8f-41e0-a028-01148c1db099                   5
# 324      Flipkart  52897612-f925-4f91-bda3-20a95f97a929                   5
# 325      Flipkart  5b97b5bc-a24a-4382-9b39-b49bc803fae7                   1
# 326      Flipkart  5da81e70-c34a-4144-a096-21463eec25f8                   1
# 327      Flipkart  616bcb01-6427-4770-aeaf-daf680849c17                   5
# 328      Flipkart  68e4a953-52c8-4fdd-b923-ed38be0eb8a2                   1
# 329      Flipkart  7a3ebf79-496c-4d43-8407-acc6bd1c3a34                   3
# 330      Flipkart  7b115f33-e4a7-4fe1-8b28-41bb5a3fb5a0                   5
# 331      Flipkart  7df3ca2a-b853-4a19-8e28-dbf5682015a7                   5
# 332      Flipkart  7e1d6d49-aa13-411a-acd4-375bd84096de                   5
# 333      Flipkart  956949f8-db07-4852-9481-d496fb77d1a7                   4
# 334      Flipkart  99174fff-c5d8-465e-9afe-4956e65463b5                   4
# 335      Flipkart  9ef8886e-d574-42bd-952f-ef5107c453b5                   1
# 336      Flipkart  ac80301b-0852-46a9-8e2b-d099c44e74a9                   1
# 337      Flipkart  c62d739e-bd81-405e-bca1-61151d2daf94                   5
# 338      Flipkart  cf2eb94a-8840-4cc8-a7f8-1fe86c0a4470                   1
# 339      Flipkart  cf2eb94a-8840-4cc8-a7f8-1fe86c0a4470                   1
# 340      Flipkart  f0906b0b-4429-45f2-b67e-5b9e9f79df90                   5
#
# [341 rows x 15 columns]

# %%
out_filter_1.dog_breed_name.unique()
# Out:
# array(['german shepherd', 'labrador', 'pug', 'dachshund', 'bernard',
#        'rottweiler', 'dane', 'bull dog', 'boxer', 'retriever', 'beagle',
#        'part', 'cocker spaniel', 'brand dog', 'tzu', 'crack', 'terrier',
#        'husky', 'mastiff', 'mutt', 'furbaby', 'bosco'], dtype=object)

# %%
out_t_per=[]
breed = out_filter_1.dog_breed_name.unique()
#print map_comp_tree
for c in breed:
    comp_rev = out_filter_1[out_filter_1.dog_breed_name == c]
    date_df = comp_rev [comp_rev.polarity == 'positive']
    #row = [c,date_df.shape[0],comp_rev.shape[0],float(date_df.shape[0]/float(comp_rev.shape[0]))*100,float((comp_rev.shape[0]-date_df.shape[0])/float(comp_rev.shape[0]))*100]
    row
    out_t_per.append(row)

# %%
out_t_per=pd.DataFrame(out_t_per)

# %%
out_t_per.columns=['Breed Name','Positive review count','Total count','Positive percentage','Negative percentage']

# %%
out_t_per.to_csv('Breed_Wise_polarity_insights.csv',sep=',',quoting=csv.QUOTE_ALL,encoding='utf-8',index=False)

# %%
out_filter_1.shape
# Out:
# (341, 15)

# %%
out1=[]
for row in df.to_dict('records'):
    key = list(row['aspect'])
    key = [x.strip(' ') for x in key]
    for i in range(0,len(key)):
        print key[i]
        if key[i] != 'dont_reply':
            row1 = [row['id'],row['source_review_id'],key[i],row['polarity']]
            out1.append(row1)
out1=pd.DataFrame(out1)
out1.columns= ['id','source_review_id','aspect_id','polarity']

# %%
out1.to_csv('aspect_id_map.csv',sep=',',quoting=csv.QUOTE_ALL,encoding='utf-8',index=False)

# %%
out1.drop_duplicates()
# Out:
#            0                                     1                       2  \
# 0     113007                       Mx10EM15V1BXFAH                     all
# 1     112962                       Mx12NXKKPRGN299                     all
# 2     112662                       Mx1533OIHOUROUT                     all
# 3     112662                       Mx1533OIHOUROUT    condition_of_product
# 4     112662                       Mx1533OIHOUROUT                   taste
# 5     112570                       Mx161SNL9KB1S36          dog-user-breed
# 6     112620                       Mx16VL8U1O076KE                     all
# 7     112620                       Mx16VL8U1O076KE      offers_n_discounts
# 8     113268                       Mx19RAE5D4NOU3T                     all
# 9     113268                       Mx19RAE5D4NOU3T              dont_reply
# 10    112885                       Mx1AGW897HCO9HT                     all
# 11    112885                       Mx1AGW897HCO9HT              dont_reply
# 12    114004                       Mx1CG72HNSR0PGF                     all
# 13    114004                       Mx1CG72HNSR0PGF              dont_reply
# 14    113132                       Mx1FK7HHIMSH9KY                     all
# 15    112679                       Mx1GH1S82D2D8KF                     all
# 16    113341                       Mx1IW5MOZJHN1K8                     all
# 17    112528                       Mx1OPD1UHH4ADV7                     all
# 18    112528                       Mx1OPD1UHH4ADV7              dont_reply
# 19    112982                       Mx1QUQF28TKPJIU                     all
# 20    113066                       Mx1RZV6V56R2BQI                     all
# 21    112993                       Mx1T2AAC8MFOVLW                     all
# 22    112993                       Mx1T2AAC8MFOVLW            convienience
# 23    112993                       Mx1T2AAC8MFOVLW              dont_reply
# 24    112886                       Mx1UCR29WE5BBWG                     all
# 25    112886                       Mx1UCR29WE5BBWG              dont_reply
# 26    112479                       Mx1YAJXC30CYY33            convienience
# 27    112479                       Mx1YAJXC30CYY33              dont_reply
# 28    113949                       Mx1ZDIVSQSH0HJ2                     all
# 29    113949                       Mx1ZDIVSQSH0HJ2                 pricing
# ...      ...                                   ...                     ...
# 7993  112021  f924758e-b9a6-4717-bc45-acd86688cc5b                     all
# 7994  112196  f9496b42-fcba-4f46-84f7-88f940b3fe21                     all
# 7995  112196  f9496b42-fcba-4f46-84f7-88f940b3fe21              dont_reply
# 7996  111308  f9f7e2f0-28d2-44c0-a3c8-8d465f7c88da           health_impact
# 7997  111308  f9f7e2f0-28d2-44c0-a3c8-8d465f7c88da                   smell
# 7998  111349  fa013193-011c-4bc8-b556-b3872d0bc684                     all
# 7999  111349  fa013193-011c-4bc8-b556-b3872d0bc684                delivery
# 8000  111349  fa013193-011c-4bc8-b556-b3872d0bc684                 pricing
# 8001  111665  fa4456e5-79b0-4264-9af7-94a92f3b4fa4            convienience
# 8002  111665  fa4456e5-79b0-4264-9af7-94a92f3b4fa4              dont_reply
# 8003  111807  fac6136c-877e-4e28-9c59-1259fa7f70a0                     all
# 8004  111807  fac6136c-877e-4e28-9c59-1259fa7f70a0              dont_reply
# 8005  111291  fbbc7b66-e8b5-4888-b5af-8a56a8e354e2                   taste
# 8006  111812  fc149b59-2da1-4f52-89a7-6f6cc33d72db                     all
# 8007  111812  fc149b59-2da1-4f52-89a7-6f6cc33d72db              dont_reply
# 8008  111896  fc2ea5b9-962a-446a-9d1e-a678636ef423                     all
# 8009  111896  fc2ea5b9-962a-446a-9d1e-a678636ef423                delivery
# 8010  111896  fc2ea5b9-962a-446a-9d1e-a678636ef423              dont_reply
# 8011  111495  fd4720d1-51fe-472d-b5ee-b604bc816919                     all
# 8012  111495  fd4720d1-51fe-472d-b5ee-b604bc816919  nutrition_ingredientst
# 8013  111495  fd4720d1-51fe-472d-b5ee-b604bc816919                  sizing
# 8014  111495  fd4720d1-51fe-472d-b5ee-b604bc816919                   taste
# 8015  112258  fd892ffc-7a01-4c06-b86f-6918e301dbb7                     all
# 8016  112258  fd892ffc-7a01-4c06-b86f-6918e301dbb7                delivery
# 8017  112258  fd892ffc-7a01-4c06-b86f-6918e301dbb7              dont_reply
# 8018  111283  ffc788cb-e77f-4f5c-bb7f-ffd6bc87b953                   taste
# 8019  111791  ffd6c583-015d-4f3e-b8b5-2df060b63410            convienience
# 8020  111791  ffd6c583-015d-4f3e-b8b5-2df060b63410              dont_reply
# 8021  111499  fff84418-d9e0-4bef-a187-22887495201b            convienience
# 8022  111499  fff84418-d9e0-4bef-a187-22887495201b              dont_reply
#
#              3
# 0     positive
# 1     positive
# 2     positive
# 3     positive
# 4     positive
# 5     positive
# 6     positive
# 7     positive
# 8     positive
# 9     positive
# 10    positive
# 11    positive
# 12    positive
# 13    positive
# 14    positive
# 15    positive
# 16    positive
# 17    positive
# 18    positive
# 19    positive
# 20    positive
# 21    positive
# 22    positive
# 23    positive
# 24    positive
# 25    positive
# 26    negative
# 27    negative
# 28    positive
# 29    positive
# ...        ...
# 7993  negative
# 7994  positive
# 7995  positive
# 7996  negative
# 7997  negative
# 7998  positive
# 7999  positive
# 8000  positive
# 8001  negative
# 8002  negative
# 8003  positive
# 8004  positive
# 8005  positive
# 8006  positive
# 8007  positive
# 8008  positive
# 8009  positive
# 8010  positive
# 8011  positive
# 8012  positive
# 8013  positive
# 8014  positive
# 8015  positive
# 8016  positive
# 8017  positive
# 8018  positive
# 8019  negative
# 8020  negative
# 8021  negative
# 8022  negative
#
# [8023 rows x 4 columns]
